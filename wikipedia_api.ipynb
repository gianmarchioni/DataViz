# %%
import requests
import json
import pandas as pd
from datetime import datetime
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
'''
This collects all people with occupation 'Singer' (Q177220) 'Songwriter' (Q753110), 'Rapper' (Q2252262), 'Guitarist' (Q855091)
and also all entities of category 'Musical Group' (Q215380)
It only selects unique entries, with a specified 'work period (start)' that starts from 1960
and also who have received at least an award.

Total number of entries is 5367, which is manageable.
'''
# Define the SPARQL query for fetching entity labels
query = """
SELECT DISTINCT ?entity ?entityLabel WHERE {
  {
    VALUES ?occupation {wd:Q177220 wd:Q753110 wd:Q2252262 wd:Q855091}
    # ?entity wdt:P106 ?occupation;
            wdt:P166 ?award;
            wdt:P2031 ?workStart.
    FILTER(YEAR(?workStart) >= 1960)
  } UNION {
    # ?entity wdt:P31 wd:Q215380;
            wdt:P166 ?award;
            wdt:P2031 ?groupWorkStart.
    FILTER(YEAR(?groupWorkStart) >= 1960)
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
LIMIT 5400
"""

# Set the endpoint URL and headers
url = "https://query.wikidata.org/sparql"
headers = {"Accept": "application/sparql-results+json"}

# Make the request
response = requests.get(url, headers=headers, params={'query': query})
data = response.json()

# Initialize an empty list to store names
people_names = []

# Iterate through the results and add names to the list
for result in data['results']['bindings']:
    people_names.append(result['entityLabel']['value'])

# Optionally, print the names or the total number of names collected
print(f"Collected a total of {len(people_names)} names.")

# %%
people_names
# Out:
# ['Bruce Springsteen',
#  'Alexandra Stan',
#  'Neil Young',
#  'Madonna',
#  'Renaud',
#  'Bob Marley',
#  'Janis Joplin',
#  'Kate Bush',
#  'Patti Smith',
#  'Cyndi Lauper',
#  'Stevie Wonder',
#  'Bruno Mars',
#  'Bob Dylan',
#  'Brigitte Fontaine',
#  'Bruce Willis',
#  'Mike Oldfield',
#  'Stefanie Heinzmann',
#  'Michael Jackson',
#  'Barbra Streisand',
#  'Céline Dion',
#  'Elton John',
#  'Miley Cyrus',
#  'Sasha Grey',
#  'Daniel Balavoine',
#  'Miranda Cosgrove',
#  'Eminem',
#  'Snoop Dogg',
#  'David Bowie',
#  'Salman Khan',
#  'Beck',
#  'Prince',
#  'Heino',
#  'Aaliyah',
#  'Britney Spears',
#  'Tupac Shakur',
#  'Lena Meyer-Landrut',
#  'Amitabh Bachchan',
#  'Whoopi Goldberg',
#  'Kana Asumi',
#  'Eleni Tzoka',
#  'Alain Souchon',
#  'Haruka Tomatsu',
#  'Thomas Fersen',
#  'Minako Kotobuki',
#  'Molly Sandén',
#  'Tim Curry',
#  'Krzysztof Grabowski',
#  'Françoise Hardy',
#  'Emiri Katō',
#  'Jane Zhang',
#  'Vanessa Paradis',
#  'Kanae Itō',
#  'Jolin Tsai',
#  'Carly Rae Jepsen',
#  'Ray William Johnson',
#  'Yui Horie',
#  'Marisa Monte',
#  'Pedro Almodóvar',
#  'Patrick Swayze',
#  'Kana Hanazawa',
#  'Rie Kugimiya',
#  'Hugh Laurie',
#  'Hisako Kanemoto',
#  'Yōko Hikasa',
#  'LL Cool J',
#  'Rainhard Fendrich',
#  'Ed Sheeran',
#  'Hans Söllner',
#  'Timbuktu',
#  'Clementina de Jesus',
#  'Anouk',
#  'Catherine Zeta-Jones',
#  'Jean-Jacques Goldman',
#  'Falco',
#  'Eddie Murphy',
#  'Roy Black',
#  'Keanu Reeves',
#  'Trey Parker',
#  'Justin Timberlake',
#  'Chris Jericho',
#  'Zac Efron',
#  'John Cale',
#  'Maaya Uchida',
#  'Ha Ji-won',
#  'Hansi Hinterseer',
#  'Gustl Bayrhammer',
#  'John Legend',
#  'Georg Danzer',
#  'Roza Rymbayeva',
#  'Nine Inch Nails',
#  'Swedish House Mafia',
#  'Earth, Wind & Fire',
#  'U2',
#  'The Jackson 5',
#  'The Beatles',
#  'Nirvana',
#  'Metallica',
#  'Iron Maiden',
#  'AC/DC',
#  'ABBA',
#  'O-Zone',
#  'Backstreet Boys',
#  'Lordi',
#  'Rammstein',
#  'No Doubt',
#  'Lyapis Trubetskoy',
#  'Led Zeppelin',
#  'The Rolling Stones',
#  'Red Hot Chili Peppers',
#  'Modern Talking',
#  'Nightwish',
#  'Radiohead',
#  "Guns N' Roses",
#  'Jan Delay',
#  'Eric Saade',
#  'Kotono Mitsuishi',
#  'Inna',
#  'Andy Lau',
#  'Roger Taylor',
#  'Kanye West',
#  'Lady Gaga',
#  'Jacky Cheung',
#  'Pharrell Williams',
#  'DJ Ötzi',
#  'Freddie Mercury',
#  'Eldar Qasımov',
#  'Jessie J',
#  'Leon Lai',
#  'Brian May',
#  'Maya Angelou',
#  'Dave Grohl',
#  'Victoria Beckham',
#  'Nigar Jamal',
#  'Amy Macdonald',
#  'Aaron Kwok',
#  'Huh Gak',
#  'Tim Minchin',
#  'Andrew Garfield',
#  'Franco Battiato',
#  'Adele',
#  'Cro',
#  'Marc Anthony',
#  'Selena',
#  'John Barrowman',
#  'John Farnham',
#  'Psy',
#  'Luísa Sobral',
#  'Yuri Stoyanov',
#  'Roberto Benigni',
#  'Joe Pesci',
#  'Ilya Oleynikov',
#  'Matthew Broderick',
#  'Taylor Swift',
#  'Hanna Schygulla',
#  'Avril Lavigne',
#  'Drake',
#  'Pete Townshend',
#  'Katja Ebstein',
#  'Amund Maarud',
#  'Garou',
#  'Kesha',
#  'Tim Bendzko',
#  'Whitney Houston',
#  'Shakira',
#  'Brie Larson',
#  'Valery Leontiev',
#  'Gwyneth Paltrow',
#  'Enya',
#  'Will Smith',
#  'Glukoza',
#  'Rihanna',
#  'Brad Paisley',
#  'Noemi',
#  'Anastacia',
#  'Scarlett Johansson',
#  'Anne Hathaway',
#  'Sara Ramirez',
#  'Robert Pattinson',
#  'Jackie Chan',
#  'Daniel Radcliffe',
#  'Nicole Kidman',
#  'Mos Def',
#  'Aerosmith',
#  'America',
#  'Juli',
#  'Roxette',
#  'Rage Against the Machine',
#  'The Drones',
#  'Can',
#  'The Clash',
#  'BAP',
#  'Majka Jeżowska',
#  'Fleetwood Mac',
#  'Gatas Parlament',
#  'Dschinghis Khan',
#  'Run-DMC',
#  'The Jezabels',
#  'Arctic Monkeys',
#  'Joy Division',
#  '2raumwohnung',
#  '120 Days',
#  'Thorleifs',
#  'Marianne Faithfull',
#  'Dire Straits',
#  'Duran Duran',
#  'Eric Clapton',
#  'The Pussycat Dolls',
#  'The Avett Brothers',
#  'Las Ketchup',
#  'Arcade Fire',
#  'Paris Hilton',
#  'Shalom',
#  'Blood, Sweat & Tears',
#  'Cher',
#  'MIA.',
#  'Buffalo Springfield',
#  'Robbie Williams',
#  'Lionel Richie',
#  'Kraftwerk',
#  'alt-J',
#  'Pesniary',
#  'Ewa Błaszczyk',
#  'Culture Club',
#  'Kylie Minogue',
#  'The Pogues',
#  'Within Temptation',
#  'Anna Maria Jopek',
#  'Anuradha Paudwal',
#  'Israel Kamakawiwoʻole',
#  'Juanes',
#  'Björk',
#  'Dima Bilan',
#  'Mariah Carey',
#  'Antonio Banderas',
#  'Sofia Rotaru',
#  'Demi Lovato',
#  'Nina Hoss',
#  'Mille Petrozza',
#  'Heike Makatsch',
#  'Anna Kendrick',
#  'Drafi Deutscher',
#  'Michael Kunze',
#  'Jasmin Tabatabai',
#  'Maximilian Mutzke',
#  'Sasha',
#  'Nolwenn Leroy',
#  'Lou Bega',
#  'Felicitas Woll',
#  'Nora Tschirner',
#  'Sabrina Setlur',
#  'Lena Valaitis',
#  'Sarah Connor',
#  'Clueso',
#  'Uschi Glas',
#  'John Kay',
#  'Sakis Rouvas',
#  'Jürgen Vogel',
#  'Rajinikanth',
#  'Jasmin Wagner',
#  'Max Raabe',
#  'Franka Potente',
#  'Hannes Wader',
#  'Peter Schilling',
#  'Kim Petras',
#  'Sexy Cora',
#  'Roger Cicero',
#  'Katja Riemann',
#  'Jimi Blue Ochsenknecht',
#  'Lisa Ekdahl',
#  'David Cryer',
#  'Ute Lemper',
#  'Barbara Sukowa',
#  'Nino de Angelo',
#  'Nicole',
#  'Amy Madigan',
#  'Maaya Sakamoto',
#  'Pat Benatar',
#  'Ana Belén',
#  'Anne Murray',
#  'Lena Philipsson',
#  'Melanie Brown',
#  'Connie Britton',
#  'Diana Gurtskaya',
#  'Márta Sebestyén',
#  'Helene Fischer',
#  'Maria Bethânia',
#  'Shelley Duvall',
#  'Gal Costa',
#  'Stacie Orrico',
#  'Natacha Atlas',
#  'Ivete Sangalo',
#  'Chavela Vargas',
#  'Silje Nergaard',
#  'Janis Ian',
#  'Taraji P. Henson',
#  'Caro Emerald',
#  'Axelle Red',
#  'Edyta Górniak',
#  'Maya Rudolph',
#  'Miss Kittin',
#  'Wanessa Camargo',
#  'Brigitte Nielsen',
#  'Chris Brown',
#  'Phil Collins',
#  'Linh Nga',
#  'Nena',
#  'Annett Louisan',
#  'Toni Braxton',
#  'Jay Rock',
#  'Carla Bruni',
#  'Jon Bon Jovi',
#  'Meat Loaf',
#  'Craig David',
#  'Katie Melua',
#  'Zal Yanovsky',
#  'Billie Piper',
#  'Andy Montañez',
#  'Annie Lennox',
#  'Keri Hilson',
#  'James Fauntleroy II',
#  'Michael Bublé',
#  'Cat Stevens',
#  'Eros Ramazzotti',
#  'Jack Antonoff',
#  'Sarah Brightman',
#  'Missy Elliott',
#  'Joanne Whalley',
#  'Ashanti',
#  'Nina Hagen',
#  'Melanie',
#  'Pink',
#  'Bonnie Tyler',
#  'Lynn Anderson',
#  'Nicki Minaj',
#  'Juan Luis Guerra',
#  'Bernice Johnson Reagon',
#  'Sophie Marceau',
#  'Karel Kryl',
#  'Kid Rock',
#  'Owen Pallett',
#  'Brandi Carlile',
#  'Daniel Landa',
#  'Patricia Kaas',
#  'Michelle Pfeiffer',
#  'Haddaway',
#  'Idina Menzel',
#  'Priyanka Chopra',
#  'Eric Gadd',
#  'Anastasiia Prykhodko',
#  'Yann Tiersen',
#  'Reinhard Mey',
#  "B'z",
#  'Chicago',
#  'Jane Horrocks',
#  'Diane Warren',
#  'Moira Kelly',
#  'Jill Hennessy',
#  'Moya Brennan',
#  'Amulet',
#  'Skin',
#  'Arash',
#  'Jonas Brothers',
#  'Eagles',
#  'Europe',
#  'Michelle',
#  'Genesis',
#  'D12',
#  'Zed',
#  'No Angels',
#  'Yes',
#  'St. Vincent',
#  'The Chicks',
#  "Destiny's Child",
#  'Daft Punk',
#  'The Kinks',
#  'Creedence Clearwater Revival',
#  'Ani Lorak',
#  'Jay Chou',
#  'Bee Gees',
#  'Melanie Fiona',
#  'Il Volo',
#  'Anna Oxa',
#  'Karpe',
#  'Ami Koshimizu',
#  'Clara Morgane',
#  'Ladyhawke',
#  'Kelly Bishop',
#  'Daveigh Chase',
#  'Van Halen',
#  'Maroon 5',
#  'Anna Tsuchiya',
#  'Esperanza Spalding',
#  'Mary Kay Place',
#  'Penny Marshall',
#  'Wir sind Helden',
#  'The Beach Boys',
#  'a-ha',
#  'Lesley Ann Warren',
#  'Hélène Ségara',
#  'Lynyrd Skynyrd',
#  'The National Bank',
#  'Day26',
#  'Counting Crows',
#  'The Yardbirds',
#  'Ajda Pekkan',
#  'Aya Hirano',
#  'ZZ Top',
#  'Zac Brown Band',
#  'Boney M.',
#  'Söhne Mannheims',
#  'Taryn Manning',
#  'Hebe Tien',
#  'Cerys Matthews',
#  'Carole Bayer Sager',
#  'Sandra Reemer',
#  'Sylvia Chang',
#  'Debra Monk',
#  'Étienne Daho',
#  'Ruth Jacott',
#  'Marie Bergman',
#  'Marjorie Estiano',
#  'Ivana Banfić',
#  'Nora Arnezeder',
#  'Yvonne Catterfeld',
#  'Rie Miyazawa',
#  'Éric Elmosnino',
#  'Maria Mena',
#  'Lola Falana',
#  'Ivy Queen',
#  'Helena Vondráčková',
#  'Nikki Yanofsky',
#  'Usher',
#  "Shaquille O'Neal",
#  'Zeca Pagodinho',
#  'Eurythmics',
#  'Grateful Dead',
#  'Hayley Kiyoko',
#  'Agnès Jaoui',
#  'Aki Toyosaki',
#  'Eve',
#  'Blondie',
#  'Donots',
#  'Tenacious D',
#  'Immortal',
#  'The Byrds',
#  'Elisa',
#  'Alexia',
#  'Alizée',
#  'Public Enemy',
#  'The Mamas & the Papas',
#  'Candy Dulfer',
#  'The Sorrow',
#  'Kate Hudson',
#  'Snap!',
#  'Freshlyground',
#  'Robert Downey Jr.',
#  'Shaka Ponk',
#  'Michèle Torr',
#  'Mnozil Brass',
#  'Arrested Development',
#  'New Kids on the Block',
#  'Sylvie Vartan',
#  'Katri Helena',
#  'The Moody Blues',
#  'The All-American Rejects',
#  'Beastie Boys',
#  'Tina Arena',
#  'The Stooges',
#  'Dixie Carter',
#  'Ewa Farna',
#  'Die Fantastischen Vier',
#  'Ewan McGregor',
#  'Owl City',
#  '22-Pistepirkko',
#  'Swizz Beatz',
#  'Sanaa Lathan',
#  'Paulinho da Viola',
#  'E Nomine',
#  'Schandmaul',
#  'Phylicia Rashad',
#  'Martine McCutcheon',
#  'Wang Leehom',
#  'Camille',
#  'Lights',
#  'Zemfira',
#  'Junko Iwao',
#  'Marion Rung',
#  'Jason Derulo',
#  'Sheila E.',
#  'Kō Shibasaki',
#  'Susan Lucci',
#  'Floor Jansen',
#  'Suzanne Somers',
#  'Ida Maria',
#  'Adrienne Barbeau',
#  "Shy'm",
#  'Anja Garbarek',
#  'Rosario Flores',
#  'Toni Basil',
#  'Silvestre Dangond',
#  'Lynda Carter',
#  'Siouxsie Sioux',
#  'Fergie',
#  'Hayden Panettiere',
#  'Thalía',
#  'Viggo Mortensen',
#  'David Gilmour',
#  'Peter Gabriel',
#  'Al Jarreau',
#  'Kasia Nosowska',
#  'Lenny Kravitz',
#  'Timbaland',
#  'Gene Pitney',
#  'Paolo Conte',
#  'Brenda Song',
#  'Kristen Bell',
#  'Björn Ulvaeus',
#  'Tyra Banks',
#  'Éric Cantona',
#  'Patrick Bruel',
#  'Meiko Kaji',
#  'Sogdiana Fedorinskaya',
#  'Jamie Foxx',
#  'Cybill Shepherd',
#  'Jack White',
#  'Ben Becker',
#  'Ina Müller',
#  'Ann Hampton Callaway',
#  'Sandra',
#  'Doro',
#  'Manuel Ortega',
#  'Mireille Mathieu',
#  'Thees Uhlmann',
#  'Kristina Bach',
#  'Kati Kovács',
#  'Jo Weil',
#  'Simone Stelzer',
#  'Tony Marshall',
#  'Nicki',
#  'Ingrid Caven',
#  'Cassandra Steen',
#  'Dieter Bohlen',
#  'Soap&Skin',
#  'Jürgen Marcus',
#  'Barbara Schöneberger',
#  'Alla Pugacheva',
#  'LaFee',
#  'C. C. Catch',
#  'Nana Abrokwa',
#  'Iris Berben',
#  'Meshell Ndegeocello',
#  'Mai Shiraishi',
#  'Kirsten Dunst',
#  'Nelly Furtado',
#  'Costa Cordalis',
#  'Christina Stürmer',
#  'Rita',
#  'Estrella Morente',
#  'Grégory Lemarchal',
#  'David Bisbal',
#  'Neil Diamond',
#  'Kid Cudi',
#  'Valeriya',
#  'Barry Manilow',
#  'Billy Connolly',
#  'Phil Lynott',
#  'apl.de.ap',
#  'Candan Erçetin',
#  'Rob Zombie',
#  'Jerney Kaagman',
#  'Vikki Carr',
#  'Sophie Zelmani',
#  'Aleksandra Kovač',
#  'Darren Criss',
#  'Terrence Howard',
#  'Russell Brand',
#  'Willow Smith',
#  'Aaron Neville',
#  'Guillaume Depardieu',
#  'Lea Salonga',
#  'MC Hammer',
#  'Nusrat Fateh Ali Khan',
#  'N.W.A.',
#  'Harumi Miyako',
#  'Shirley Temple',
#  'Annie',
#  'Rod Evans',
#  'Kaizers Orchestra',
#  'Niagara',
#  'Bijele Strijele',
#  'Atomic',
#  'Buena Vista Social Club',
#  'Maná',
#  'Fleet Foxes',
#  'Bel Canto',
#  'Tom Jones',
#  'Shadowfax',
#  'TRF',
#  'The Seekers',
#  'Fausto Leali',
#  'Arvingarna',
#  'Belphegor',
#  'Lady A',
#  'Aaron Tveit',
#  'Grzegorz Turnau',
#  'Jeanette Biedermann',
#  'Imagine Dragons',
#  'Luis Enrique',
#  'Tegan and Sara',
#  'Bell Orchestre',
#  'The Temptations',
#  'Asleep at the Wheel',
#  'Manic Street Preachers',
#  'Small Faces',
#  'Michał Bajor',
#  'Pete Philly and Perquisite',
#  'Bloodsucking Zombies From Outer Space',
#  'Village People',
#  'Marcus Miller',
#  'Van Dik Hout',
#  'Turbonegro',
#  'Chow Yun-fat',
#  'Carly Simon',
#  'Rod Stewart',
#  'Electric Light Orchestra',
#  '3JS',
#  'Steely Dan',
#  'Kings of Convenience',
#  'Sepultura',
#  'Flying Steps',
#  'Kool & The Gang',
#  'Helena Paparizou',
#  'Grzegorz Ciechowski',
#  'Kotiteollisuus',
#  'Madcon',
#  'Iggy Pop',
#  'Afromental',
#  'Garrison Keillor',
#  'Lyudmila Petrushevskaya',
#  'Mylène Farmer',
#  'Pitbull',
#  'Mika',
#  'Olivia Newton-John',
#  'Mandy Moore',
#  'Tracy Chapman',
#  'Merle Haggard',
#  'Tom Waits',
#  'Goldie Hawn',
#  'Seth MacFarlane',
#  'Alyssa Milano',
#  'Mike Myers',
#  'Sally Field',
#  'Joaquin Phoenix',
#  'Paula Abdul',
#  'Lou Reed',
#  'Leona Lewis',
#  'Billy Crystal',
#  'Kelly Rowland',
#  'Marie Fredriksson',
#  'Uwe Ochsenknecht',
#  'Nick Cave',
#  'Zooey Deschanel',
#  'Jason Mraz',
#  'Lara Fabian',
#  'Laura Benanti',
#  'Joe Cocker',
#  'Danny Glover',
#  'Kate Ryan',
#  'Zendaya',
#  'Matt Bellamy',
#  'Rufus Wainwright',
#  'Sade Adu',
#  'Danny Elfman',
#  'Billy Joel',
#  'Bette Midler',
#  'Sissy Spacek',
#  'Wesley Snipes',
#  'Steven Tyler',
#  'Ryan Gosling',
#  'Amanda Seyfried',
#  'DJ BoBo',
#  'Ne-Yo',
#  'Orange Range',
#  'Tinariwen',
#  'Caetano Veloso',
#  'Peter Gallagher',
#  'James Taylor',
#  'Luther Vandross',
#  'Opus',
#  'TLC',
#  'The Band',
#  'Lasse Stefanz',
#  'Amaral',
#  'Chevy Chase',
#  'Ann Wilson',
#  'Don Johnson',
#  'Jason Alexander',
#  'Silly',
#  'Anita Baker',
#  'Megumi Ogata',
#  'Beatsteaks',
#  'Bon Jovi',
#  'Don Omar',
#  'Tom Petty',
#  'Siddharta',
#  'Glenn Hughes',
#  'Haloo Helsinki!',
#  'Jeff Bennett',
#  'Shane Dawson',
#  'Américo',
#  'Jim Cummings',
#  'Rokia Traoré',
#  'In Flames',
#  'Sportfreunde Stiller',
#  'Coolio',
#  'Hot Chelle Rae',
#  'Biermösl Blosn',
#  'Kana Nishino',
#  'Tommy Emmanuel',
#  'Sanjay Dutt',
#  'Drive-By Truckers',
#  'Camarón de la Isla',
#  'Damien Rice',
#  'Irina Dorofeeva',
#  'Martina McBride',
#  'Bobby McFerrin',
#  'Toni Polster',
#  'Akademie für Alte Musik Berlin',
#  'Shonentai',
#  'Kyoko Fukada',
#  "Gigi D'Agostino",
#  'Bilderbuch',
#  'Sabaton',
#  'Li Bingbing',
#  'Yukiko Okada',
#  'Ane Brun',
#  'Minori Chihara',
#  'Mala Rodríguez',
#  'Chris Farley',
#  'Little Big Town',
#  'Bertine Zetlitz',
#  'Spider Murphy Gang',
#  'Mandrage',
#  'Sean Paul',
#  'Hayley Williams',
#  'Morrissey',
#  'Elvis Costello',
#  'Joni Mitchell',
#  'Bradley Cooper',
#  'Zhao Wei',
#  'Zhou Xun',
#  'Abigail Breslin',
#  'Isaac Hayes',
#  'Manu Chao',
#  'Ian Gillan',
#  'Lim Hyung-joo',
#  'Elisabeth Shue',
#  'France Gall',
#  'Sheryl Crow',
#  'Ziggy Marley',
#  'Kate Winslet',
#  'Victoria Abril',
#  'Vanessa Williams',
#  'Amandla Stenberg',
#  'Wyclef Jean',
#  'Dana International',
#  'Paulina Rubio',
#  'Billy Bob Thornton',
#  'Leighton Meester',
#  'Beth Hart',
#  'Mary Elizabeth Winstead',
#  'Bella Thorne',
#  'David Hasselhoff',
#  'Jo Nesbø',
#  'Luz Casal',
#  'Gilda Radner',
#  'Jazmine Sullivan',
#  'Ursula Rucker',
#  'Renee Olstead',
#  'Ashley Johnson',
#  'Sainkho Namtchylak',
#  'Kevin Mahogany',
#  'Najwa Nimri',
#  'Chava Alberstein',
#  'Amel Bent',
#  'Mandy Patinkin',
#  'Meredith Monk',
#  'Rita Lee',
#  'Martha Plimpton',
#  'Kirsti Sparboe',
#  'Andrea Corr',
#  'Fann Wong',
#  'Caterina Caselli',
#  'Yardena Arazi',
#  'Rossy de Palma',
#  'Shawn Colvin',
#  'Yumi Matsutoya',
#  'Maija Vilkkumaa',
#  'Namie Amuro',
#  'Chantal Kreviazuk',
#  'Concha Buika',
#  'Hikari Mitsushima',
#  "Olivia d'Abo",
#  'Rickie Lee Jones',
#  'Sheila',
#  'Edie McClurg',
#  'Anita Skorgan',
#  'Nancy Wilson',
#  'Kastelruther Spatzen',
#  'Big Bang',
#  'Gary Barlow',
#  'Martin Short',
#  'Peter Pan Speedrock',
#  'Shining',
#  'Under Byen',
#  'DJ DOC',
#  'Giorgia',
#  'The Monkees',
#  'Arashi',
#  'Babyface',
#  'Chico Buarque',
#  'Journey',
#  'Hanson',
#  'Sharp',
#  'David Byrne',
#  'The Hollies',
#  'Emmanuel',
#  'John Mahoney',
#  'Jun Matsumoto',
#  'Valérie Lemercier',
#  'Ali Farka Touré',
#  'Tanel Padar',
#  'Architects',
#  'Audrey Horne',
#  'Die Flippers',
#  'Urszula',
#  'Alice Cooper',
#  '77 Bombay Street',
#  'Bert Jansch',
#  'Keren Ann',
#  'Johnny Winter',
#  "Jane's Addiction",
#  'Kris Kristofferson',
#  'Jessica Paré',
#  'Kōichi Yamadera',
#  'Leonid Agutin',
#  'Karin Dreijer',
#  'Eliane Elias',
#  'Sandrine Kiberlain',
#  'Georgina Verbaan',
#  'John Mellencamp',
#  'Black Veil Brides',
#  'Bill Withers',
#  'Lill Lindfors',
#  'Sérgio Mendes',
#  'Joe Bonamassa',
#  'Grandmaster Flash and the Furious Five',
#  'Debbie Allen',
#  'Mathilda May',
#  'Asaf Avidan',
#  'Dyanna Lauren',
#  'Fania All-Stars',
#  'Anika Noni Rose',
#  'Veronica Maggio',
#  'Panic! At The Disco',
#  'High on Fire',
#  'LiSA',
#  'James Morrison',
#  'Joan Manuel Serrat',
#  'Robert Wyatt',
#  'James Marsters',
#  'Daniel Powter',
#  'Tony Kakko',
#  'Donovan',
#  'Brian Wilson',
#  'Kevin McHale',
#  'José González',
#  'Vivek',
#  'Michael Richards',
#  'Michael Bolton',
#  'Salif Keita',
#  'Harry Connick Jr.',
#  'Tom Hulce',
#  'Vanilla Ice',
#  'Michael von der Heide',
#  'Jónsi',
#  'Keith Urban',
#  'Jerry Garcia',
#  'Lee "Scratch" Perry',
#  'Blixa Bargeld',
#  'Salvatore Adamo',
#  'Per Gessle',
#  'Dmitry Koldun',
#  'José Feliciano',
#  'Don Henley',
#  'Mark Salling',
#  'Andy Samberg',
#  'Patrick Stump',
#  'Udo Lindenberg',
#  'Dan Balan',
#  'Cássia Eller',
#  'Lykke Li',
#  'Alsou',
#  'Chen Hao',
#  'Cecilia Cheung',
#  'Lou Doillon',
#  'Michele Lee',
#  'Paula Cole',
#  'Olivia Ruiz',
#  'Patti LuPone',
#  'Ana Torroja',
#  'Jenifer',
#  'Melissa Etheridge',
#  'Titiyo',
#  'Shizuka Itō',
#  'Ruby Lin',
#  'Teresa Salgueiro',
#  'Mariana Popova',
#  'Mary Chapin Carpenter',
#  'Meisa Kuroki',
#  "Paige O'Hara",
#  'Mika Nakashima',
#  'Niña Pastori',
#  'Debby Boone',
#  'Olga Tañón',
#  'Lee Jeong-hyeon',
#  'Valentina Tolkunova',
#  'Darin Zanyar',
#  'Jonathan Rhys Meyers',
#  'Jan Josef Liefers',
#  'Ian Anderson',
#  'Benny Andersson',
#  'Sido',
#  'Bill Cosby',
#  'Lauryn Hill',
#  'Garth Brooks',
#  'John Mayer',
#  'John Goodman',
#  'Barry White',
#  'Alyosha',
#  'Bob Geldof',
#  'Chris Colfer',
#  'Youssou N’Dour',
#  'Svetlana Loboda',
#  'Sean Combs',
#  'Jane Birkin',
#  'Carrie Underwood',
#  'Billy Ocean',
#  'Ray Davies',
#  'Stephen Stills',
#  'Michel Sardou',
#  'Joe Walsh',
#  'Patrick Wilson',
#  'Frank Ocean',
#  'Matthew Good',
#  'Jackson Browne',
#  'Kurt Nilsen',
#  'Michael W. Smith',
#  'Taj Mahal',
#  'El General',
#  'Tim McGraw',
#  'Kappei Yamaguchi',
#  'Drew Carey',
#  'Luan Santana',
#  'Midge Ure',
#  'John Stamos',
#  'Tech N9ne',
#  'Miguel Bosé',
#  'Sonny Chiba',
#  'Steven Van Zandt',
#  'Max Boyce',
#  'Martin Solveig',
#  'Ryan Tedder',
#  'The-Dream',
#  'Sarah McLachlan',
#  'Silvi Vrait',
#  'Zoë Kravitz',
#  'Jewel',
#  'Anggun',
#  'Anna Prucnal',
#  'Katey Sagal',
#  'Gigliola Cinquetti',
#  'Nana Mizuki',
#  'Naya Rivera',
#  'Zsuzsa Koncz',
#  'Yannick Noah',
#  'Heather Morris',
#  'PJ Harvey',
#  'Lola Ponce',
#  'Dianna Agron',
#  'Jada Pinkett Smith',
#  'Toni Collette',
#  'Adam Levine',
#  'Gilberto Gil',
#  'Marija Šerifović',
#  'Tina Karol',
#  'Michael Palin',
#  'Zoran Predin',
#  'Jørn Lande',
#  'Mary J. Blige',
#  ...]

# %%
# Initialization
base_url = "https://en.wikipedia.org/w/api.php"
session = requests.Session()
headers = {'User-Agent': 'YourAppName/1.0 (your-email@example.com)'}
names_2023_visits = []
article_found_counter = 0

# Loop through each name in the people_names list
for name in people_names:
    # Encode the name for URL
    page_title_formatted = requests.utils.quote(name.replace(' ', '_'))
    
    # Initialize total views for 2023
    total_views_2023 = 0
    
    # Construct the URL for fetching pageviews
    pageviews_url = f"https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia/all-access/user/{page_title_formatted}/monthly/20230101/20231231"
    
    # Make the request
    response_pageviews = requests.get(pageviews_url, headers=headers)
    if response_pageviews.status_code == 200:
        pageviews_data = response_pageviews.json().get('items', [])
        
        # Sum up views for 2023
        for item in pageviews_data:
            total_views_2023 += item.get('views', 0)
        
        # Check if any views were found and append to the data list
        if total_views_2023 > 0:
            names_2023_visits.append({"name": name, "2023_visits": total_views_2023})
            article_found_counter += 1
        else:
            print(f"No views data found for {name}")
    else:
        print(f"Failed to fetch pageviews for {name}")

# After collecting data, create a DataFrame
names_visits_df = pd.DataFrame(names_2023_visits)

# Print the number of articles found and the total number of names processed
print(f"{article_found_counter} articles found with views data, out of the {len(people_names)} in the list")
# Out:
# Failed to fetch pageviews for AC/DC
# Failed to fetch pageviews for Anastasiia Prykhodko
# Failed to fetch pageviews for Bloodsucking Zombies From Outer Space
# Failed to fetch pageviews for Lee Jeong-hyeon
# Failed to fetch pageviews for Polad Bulbuloghlu
# Failed to fetch pageviews for Band ohne Namen
# No views data found for deLillos
# Failed to fetch pageviews for Ewa Bem
# Failed to fetch pageviews for Lyna bonasera
# Failed to fetch pageviews for Tammin Pamela Sursok
# Failed to fetch pageviews for María Ostiz
# No views data found for k-os
# Failed to fetch pageviews for Darius & Finlay
# Failed to fetch pageviews for Françis Bebey
# No views data found for Ryan Conner
# Failed to fetch pageviews for Marie-Paule Belle
# Failed to fetch pageviews for Jang Dong-geon
# Failed to fetch pageviews for Petr Kotvald
# Failed to fetch pageviews for Allain Leprest
# Failed to fetch pageviews for Fruzsina Kovácsovics
# Failed to fetch pageviews for Clowns & Helden
# Failed to fetch pageviews for Galandum Galundaina
# Failed to fetch pageviews for Alda Risma
# Failed to fetch pageviews for Dylan Riley Synder
# Failed to fetch pageviews for Andrea Szulák
# Failed to fetch pageviews for Izabella Olejnik
# Failed to fetch pageviews for Teresa Tutinas
# Failed to fetch pageviews for OqueStrada
# Failed to fetch pageviews for Zarifa Pashaevna Mgoyan
# Failed to fetch pageviews for Anastasija Stockaja
# Failed to fetch pageviews for Zoltán Bereczki
# Failed to fetch pageviews for Kaublas
# Failed to fetch pageviews for Shigeaki Katō
# Failed to fetch pageviews for Adam Sami
# Failed to fetch pageviews for Ireesha
# Failed to fetch pageviews for Ginette Acevedo
# Failed to fetch pageviews for Git Persson
# Failed to fetch pageviews for Julian le Play
# Failed to fetch pageviews for Adrienn Zsédenyi
# No views data found for Erik van Muiswinkel
# Failed to fetch pageviews for Jacek Wójcicki
# Failed to fetch pageviews for Loeki Knol
# Failed to fetch pageviews for Taisiia Povalii
# Failed to fetch pageviews for Pasión Vega
# Failed to fetch pageviews for Dirk Scheele
# Failed to fetch pageviews for Chinmayi Sripada
# Failed to fetch pageviews for Ekaterina Aleksandrovna Klimova
# Failed to fetch pageviews for Curt Fortin
# Failed to fetch pageviews for Anatol Yarmolyenka
# Failed to fetch pageviews for Nazarii Yaremchuk
# Failed to fetch pageviews for Milan van Weelden
# Failed to fetch pageviews for Giulia y los Tellarini
# Failed to fetch pageviews for Dinä Ğäripevä
# Failed to fetch pageviews for Willem Nijholt (1934-2023)
# Failed to fetch pageviews for Jean-Philippe Marthély
# Failed to fetch pageviews for Kasper van Kooten
# Failed to fetch pageviews for Ignacio Elguero de Olavide
# Failed to fetch pageviews for Noel Molina
# Failed to fetch pageviews for ’Til Tuesday
# Failed to fetch pageviews for Liam Pane
# Failed to fetch pageviews for Georgette Lemaire
# Failed to fetch pageviews for Arturo Cavero Velásquez
# Failed to fetch pageviews for Sylvie Hoarau
# Failed to fetch pageviews for Tanya Saint-Val
# Failed to fetch pageviews for Q4281314
# Failed to fetch pageviews for Q4285963
# Failed to fetch pageviews for Svetlana Nazarenko
# Failed to fetch pageviews for Sergey Makhovikov
# Failed to fetch pageviews for Natalya Mogilevskaya
# Failed to fetch pageviews for Soso Pavliashvilli
# Failed to fetch pageviews for Ia Ninidze
# Failed to fetch pageviews for Tatiana Ovsiyenko
# Failed to fetch pageviews for Nadezhda Mikulich
# Failed to fetch pageviews for Oleg Nesterov
# Failed to fetch pageviews for Faiq Ağayev
# No views data found for Tungtvann
# Failed to fetch pageviews for Aleksandr Inshakov
# Failed to fetch pageviews for İzzet Altınmeşe
# Failed to fetch pageviews for Viktor Andriyenko
# Failed to fetch pageviews for Q4131532
# Failed to fetch pageviews for Olga Zarubina
# Failed to fetch pageviews for Georgy Deliev
# Failed to fetch pageviews for Yekaterina Zhemchuzhnaya
# Failed to fetch pageviews for Larisa Gavrilina
# Failed to fetch pageviews for Rodion Gazmanov
# Failed to fetch pageviews for Nikolay Gnatyuk
# Failed to fetch pageviews for Lyalya Zhemchuzhnaya
# Failed to fetch pageviews for Q4080858
# No views data found for Yevgeny Ponasenkov
# Failed to fetch pageviews for Sergey Voytenko
# Failed to fetch pageviews for José-Apeles Santolaria de Puey y Cruells
# Failed to fetch pageviews for Baloğlan Əşrəfov
# Failed to fetch pageviews for Vladimir Presnyakov Jr
# Failed to fetch pageviews for Irina Bezrukova
# Failed to fetch pageviews for Aleksandr Vilkov
# Failed to fetch pageviews for Yelena Perova
# Failed to fetch pageviews for Yadviga Paplawskaya
# Failed to fetch pageviews for Victor Rakov
# Failed to fetch pageviews for Q4477816
# Failed to fetch pageviews for Vladimir Shakhrin
# Failed to fetch pageviews for Kōji Yamamoto
# Failed to fetch pageviews for Viktoriya Tsyganova
# Failed to fetch pageviews for Arkady Khoralov
# Failed to fetch pageviews for Igor Ugolnikov
# Failed to fetch pageviews for Tamara Yandiyeva
# Failed to fetch pageviews for Irina Konstantinova Tsyvina
# Failed to fetch pageviews for Q4241411
# Failed to fetch pageviews for Q4269189
# Failed to fetch pageviews for Q4405746
# Failed to fetch pageviews for Tatyana Zykina
# Failed to fetch pageviews for Anatoly Kasheparov
# Failed to fetch pageviews for Yulia Kovalchuk
# Failed to fetch pageviews for Igor Slutsky
# Failed to fetch pageviews for Boris Smolkin
# Failed to fetch pageviews for Igor Kuschpler
# Failed to fetch pageviews for Stella Djanni
# Failed to fetch pageviews for Stepan Kazanin
# Failed to fetch pageviews for Elena Stepanenko
# Failed to fetch pageviews for Denis Klyaver
# Failed to fetch pageviews for Tatiana Lazareva
# Failed to fetch pageviews for Kira Smirnova
# Failed to fetch pageviews for Mark Tishman
# Failed to fetch pageviews for Mikhail Turetsky
# Failed to fetch pageviews for Jon van Eerd
# Failed to fetch pageviews for Leri Vinn
# Failed to fetch pageviews for Carin Lundin
# Failed to fetch pageviews for Veronica P. Kruglova
# Failed to fetch pageviews for Vadim Samoylov
# Failed to fetch pageviews for Velove Vexia
# Failed to fetch pageviews for Laila Andersson-Palme
# Failed to fetch pageviews for Josefine Jinder
# Failed to fetch pageviews for Ragga Gísla
# Failed to fetch pageviews for Ahmet Şafak
# No views data found for Brandy Aniston
# Failed to fetch pageviews for Claes Janson
# Failed to fetch pageviews for Félix Granado
# Failed to fetch pageviews for Cecilia Díaz
# Failed to fetch pageviews for Yuyee Alissa Carmela
# Failed to fetch pageviews for Jan Hammarlund
# Failed to fetch pageviews for Candra Darusman
# Failed to fetch pageviews for Erland Hagegård
# Failed to fetch pageviews for Pablo Ilabaca
# Failed to fetch pageviews for Patricia López-Menadier
# Failed to fetch pageviews for Yonit Tobi
# Failed to fetch pageviews for Yishai Lapidot
# Failed to fetch pageviews for Marcelo Cezán
# Failed to fetch pageviews for Mustafa Sağyaşar
# Failed to fetch pageviews for M. Daud Kilau
# Failed to fetch pageviews for Q6542796
# Failed to fetch pageviews for Jan Plestenjak
# Failed to fetch pageviews for Amir Dadon
# Failed to fetch pageviews for Wolna Grupa Bukowina
# Failed to fetch pageviews for Hana Roth
# Failed to fetch pageviews for Aviv Guedj
# Failed to fetch pageviews for Tali Oren
# No views data found for très.b
# Failed to fetch pageviews for Cappella Gedanensis
# Failed to fetch pageviews for Norihiko Hashida and the Shoebelts
# Failed to fetch pageviews for Vibafemba
# Failed to fetch pageviews for Stenia Kozłowska
# Failed to fetch pageviews for Wojciech Korda
# Failed to fetch pageviews for George Yamamoto
# Failed to fetch pageviews for Grażyna Łobaszewska
# Failed to fetch pageviews for Boogart
# Failed to fetch pageviews for Danuta Błażejczyk
# Failed to fetch pageviews for Danuta Stankiewicz
# Failed to fetch pageviews for A Roda
# Failed to fetch pageviews for Łydka Grubasa
# Failed to fetch pageviews for Yasuko Naitō
# Failed to fetch pageviews for Dænsebændet
# Failed to fetch pageviews for Akemi Ishii
# Failed to fetch pageviews for Anna Szałapak
# Failed to fetch pageviews for Witold Żołądkiewicz
# Failed to fetch pageviews for Za!
# Failed to fetch pageviews for Willy Clay Band
# Failed to fetch pageviews for Bratři Ebenové
# Failed to fetch pageviews for Yasuko Kuwata
# Failed to fetch pageviews for Satoshi Ikeda
# Failed to fetch pageviews for Tohru Watanabe
# Failed to fetch pageviews for Machiko Watanabe
# Failed to fetch pageviews for Izabela Skrybant-Dziewiątkowska
# Failed to fetch pageviews for Sandra Kolstad
# No views data found for Pop Design
# Failed to fetch pageviews for Amy Search
# No views data found for Čuki
# Failed to fetch pageviews for Seikō Itō
# Failed to fetch pageviews for Isao Bitō
# Failed to fetch pageviews for Jazz Band Ball Orchestra
# Failed to fetch pageviews for Krystyna Prońko
# Failed to fetch pageviews for Ushirokara Haiyoritai
# Failed to fetch pageviews for Leszek Wójtowicz
# Failed to fetch pageviews for Djevel
# Failed to fetch pageviews for Nataliya Shelepnytska
# Failed to fetch pageviews for Krystyna Świątecka
# Failed to fetch pageviews for Jan Wojdak
# Failed to fetch pageviews for Montée
# No views data found for Asamisimasa
# Failed to fetch pageviews for Miyako Ōtsuki
# Failed to fetch pageviews for Karyudo
# Failed to fetch pageviews for Lech Czerkas
# Failed to fetch pageviews for Anna Roig i L'ombre de ton chien
# Failed to fetch pageviews for Kumiko Mori
# Failed to fetch pageviews for Akiko Kanazawa
# Failed to fetch pageviews for Nacho Mañó
# Failed to fetch pageviews for Blaumut
# Failed to fetch pageviews for Jannicke Abrahamsen
# Failed to fetch pageviews for Kaia Huuse
# Failed to fetch pageviews for Marek Ałaszewski
# Failed to fetch pageviews for Natalia Fiedorczuk-Cieślak
# Failed to fetch pageviews for Jørn Simen Øverli
# Failed to fetch pageviews for Pinky & Killers
# Failed to fetch pageviews for Q12527667
# Failed to fetch pageviews for Q12557366
# No views data found for Julie Sudiro
# Failed to fetch pageviews for Ohad Hitman
# Failed to fetch pageviews for Aryeh Moskona
# Failed to fetch pageviews for Yitzhak Klapter
# Failed to fetch pageviews for Neno Warisman
# Failed to fetch pageviews for D J Dave
# Failed to fetch pageviews for Shlomo Ydov
# Failed to fetch pageviews for Ola Schur Selektar
# Failed to fetch pageviews for Äsxät Xismätef
# Failed to fetch pageviews for Nicolae Furdui Iancu
# Failed to fetch pageviews for Dan Toren
# Failed to fetch pageviews for Tiki Dayan
# Failed to fetch pageviews for Khamduna Timergalieva
# Failed to fetch pageviews for Eric Berman
# Failed to fetch pageviews for Q12837574
# Failed to fetch pageviews for Q12843329
# Failed to fetch pageviews for Q14562502
# Failed to fetch pageviews for Nasiba Abdullayeva
# Failed to fetch pageviews for Səkinə İsmayılova
# Failed to fetch pageviews for Abbas Bağırov
# Failed to fetch pageviews for Nazim Ağayev
# Failed to fetch pageviews for Ağadadaş Ağayev
# Failed to fetch pageviews for Sənubər İsgəndərli
# Failed to fetch pageviews for Thomas Hasani Chauke
# Failed to fetch pageviews for Aygün Bayramova
# Failed to fetch pageviews for Rotem Cohen
# Failed to fetch pageviews for Shlomi Shaban
# Failed to fetch pageviews for Nikolay Korshilov
# Failed to fetch pageviews for Kaiser Franz Josef
# Failed to fetch pageviews for Ballade!
# Failed to fetch pageviews for Elnare Xelilova
# Failed to fetch pageviews for Məhəbbət Kazımov
# Failed to fetch pageviews for Tahir Akber
# Failed to fetch pageviews for La Original Banda El Limón
# Failed to fetch pageviews for Q16365792
# Failed to fetch pageviews for Q16366624
# Failed to fetch pageviews for Q16377988
# Failed to fetch pageviews for Vicente Soto “Sordera”
# Failed to fetch pageviews for İlhamə Quliyeva
# Failed to fetch pageviews for Kobus Algra
# Failed to fetch pageviews for Aybəniz Haşımova
# Failed to fetch pageviews for Mädīna Erälīeva
# Failed to fetch pageviews for Adam Ďurica
# Failed to fetch pageviews for Rasul Karabulatov
# Failed to fetch pageviews for Simona Weiss
# Failed to fetch pageviews for Guadalupe Plata
# Failed to fetch pageviews for Andrej Aleksin
# Failed to fetch pageviews for Steinar Albrigtsen
# Failed to fetch pageviews for Teymur Mustafayev
# Failed to fetch pageviews for Thea Paluoja
# Failed to fetch pageviews for Marina Voica
# Failed to fetch pageviews for Matías Vega Rojas
# Failed to fetch pageviews for Əli Haqverdiyev
# Failed to fetch pageviews for Daniel Wayne Sermón
# Failed to fetch pageviews for Peter Bič Project
# Failed to fetch pageviews for Zainab Makhaeva
# Failed to fetch pageviews for Vasily Uriyevsky
# Failed to fetch pageviews for Akram Poladov
# Failed to fetch pageviews for Anna Pietrzak
# Failed to fetch pageviews for Q19614050
# Failed to fetch pageviews for Inna Afanasieva
# Failed to fetch pageviews for Q20026213
# Failed to fetch pageviews for Odunlade Jonathan Adekola
# Failed to fetch pageviews for Viktoriya Mazur
# Failed to fetch pageviews for Sophie Elise
# Failed to fetch pageviews for Nuška Drašček
# Failed to fetch pageviews for Andrii Zalisko
# Failed to fetch pageviews for Elsa Mangue
# Failed to fetch pageviews for Natasha Wilona
# Failed to fetch pageviews for Vladimir Berelet
# Failed to fetch pageviews for Jacek Beler
# Failed to fetch pageviews for Meral Polat
# Failed to fetch pageviews for Liat Itzhaki
# Failed to fetch pageviews for Q20560125
# Failed to fetch pageviews for Q20594144
# Failed to fetch pageviews for Marfa Kolesova-Rastorguyeva
# Failed to fetch pageviews for Vladlena Ivanova
# Failed to fetch pageviews for Q25647074
# Failed to fetch pageviews for Q25686076
# Failed to fetch pageviews for Galina Uletova
# Failed to fetch pageviews for Tatyana Denisova
# Failed to fetch pageviews for Eva Crutzen
# Failed to fetch pageviews for Radik Yuliakshin
# Failed to fetch pageviews for Guillermo Rodríguez Godínez
# Failed to fetch pageviews for Zoya Bernikova
# Failed to fetch pageviews for Okkultokrati
# Failed to fetch pageviews for Ionuț Silaghi de Oaș
# Failed to fetch pageviews for Spanish Brass Luur Metalls
# Failed to fetch pageviews for Ničim izazvan
# Failed to fetch pageviews for Vadim Ananyev
# Failed to fetch pageviews for Kasia Lins
# Failed to fetch pageviews for Kingsley ChinweikeOkonkwo
# Failed to fetch pageviews for Kizz Danielb
# Failed to fetch pageviews for Innersound
# Failed to fetch pageviews for Q28354918
# Failed to fetch pageviews for Shekhinah Thandi Donnell
# Failed to fetch pageviews for Shô Kiryûin
# Failed to fetch pageviews for Marina Alekseyeva
# Failed to fetch pageviews for Anatoliy Tsoy
# Failed to fetch pageviews for Justyna Święs
# Failed to fetch pageviews for Winning Jah
# Failed to fetch pageviews for Minaya Penzhalieva
# Failed to fetch pageviews for Antonela Doko
# Failed to fetch pageviews for Hańba!
# Failed to fetch pageviews for Neli Bahuslawskaya
# Failed to fetch pageviews for Smoking Souls
# Failed to fetch pageviews for Élida Almeida
# Failed to fetch pageviews for Aci Resti
# Failed to fetch pageviews for Täslimä Nizami
# Failed to fetch pageviews for Tamara Agapova
# Failed to fetch pageviews for Shiny Sisters
# Failed to fetch pageviews for Dårlig Vane
# Failed to fetch pageviews for millennium parade
# Failed to fetch pageviews for The Rheingans Sisters
# Failed to fetch pageviews for Q56188234
# Failed to fetch pageviews for Q56368788
# Failed to fetch pageviews for Q60831153
# Failed to fetch pageviews for Q61122107
# Failed to fetch pageviews for Ol'ga Lozovaya
# Failed to fetch pageviews for Vitalie Advahov
# Failed to fetch pageviews for GURLS
# Failed to fetch pageviews for Thomas Jesatko
# Failed to fetch pageviews for Rəhilə Bəndəliyeva
# Failed to fetch pageviews for Eduard Pelageychenko
# Failed to fetch pageviews for Jojo Maronttinni
# Failed to fetch pageviews for Natal'ya Rozhkova
# Failed to fetch pageviews for Lildami
# Failed to fetch pageviews for Evgenia Gorokhovskaya
# Failed to fetch pageviews for soltera
# No views data found for Rekman Seller
# Failed to fetch pageviews for Princesa Alba
# Failed to fetch pageviews for Hagle
# Failed to fetch pageviews for Gölzädä Safiullina
# Failed to fetch pageviews for T.K. Mathabela
# Failed to fetch pageviews for Muddy What?
# Failed to fetch pageviews for Joe Vitale Jr
# Failed to fetch pageviews for Yosh Whale
# Failed to fetch pageviews for Q65275772
# Failed to fetch pageviews for Yuto Tatsumi
# Failed to fetch pageviews for Flukten
# Failed to fetch pageviews for Fado Bicha
# Failed to fetch pageviews for Q76603817
# Failed to fetch pageviews for Rosa da Silva
# Failed to fetch pageviews for Katya Adushkina
# Failed to fetch pageviews for Q85999367
# Failed to fetch pageviews for Sara Renar
# Failed to fetch pageviews for Miko Creed
# Failed to fetch pageviews for Fumiko Uno
# Failed to fetch pageviews for Q114055959
# Failed to fetch pageviews for Krúbi
# Failed to fetch pageviews for Cegra Karl
# Failed to fetch pageviews for Jannette Chao
# Failed to fetch pageviews for Vasiliy Shtefutsa
# Failed to fetch pageviews for MC Cabelinho
# Failed to fetch pageviews for Sasha Popova
# Failed to fetch pageviews for Natalya Gerasimova
# Failed to fetch pageviews for Lucía Muñoz Maldonado
# Failed to fetch pageviews for Belén Aguilera
# Failed to fetch pageviews for Cris MJ
# Failed to fetch pageviews for Rayne Almeida
# Failed to fetch pageviews for Alenka Star Be
# Failed to fetch pageviews for Ayaz Babayev
# Failed to fetch pageviews for Sandra Guida
# Failed to fetch pageviews for Froukje
# Failed to fetch pageviews for Xamdam Sobirov
# Failed to fetch pageviews for Kamila Cree
# Failed to fetch pageviews for Liza Myalik
# Failed to fetch pageviews for Sara Fajira
# Failed to fetch pageviews for Mushkaa
# Failed to fetch pageviews for Marcianeke
# Failed to fetch pageviews for Fathia Izzati
# Failed to fetch pageviews for Kristina Ramazanova
# Failed to fetch pageviews for Röstäm Mälikef
# Failed to fetch pageviews for ADONXS
# Failed to fetch pageviews for Xäbib
# Failed to fetch pageviews for Färidä Safina
# Failed to fetch pageviews for Alexander Dei Russ
# Failed to fetch pageviews for Leonardo San Martín
# Failed to fetch pageviews for Mesach Semakula
# Failed to fetch pageviews for Eszter Kovács
# Failed to fetch pageviews for Nato Metonidze
# Failed to fetch pageviews for Q109337291
# Failed to fetch pageviews for Q115773779
# Failed to fetch pageviews for Q115925397
# Failed to fetch pageviews for Ariana Rahera Tikao
# Failed to fetch pageviews for Lil Xacah
# Failed to fetch pageviews for Robleis
# Failed to fetch pageviews for Nico Donys
# Failed to fetch pageviews for Q124820631
# Failed to fetch pageviews for Madelyn Ann
# Failed to fetch pageviews for Artur Babich
# Failed to fetch pageviews for Christine Tassan
# Failed to fetch pageviews for Ruth Vazquez
# No views data found for Arawinda Kirana
# Failed to fetch pageviews for La Insuperable
# Failed to fetch pageviews for Shirinov, Olimbek Mahmadbekovuch
# Failed to fetch pageviews for Guajaja
# Failed to fetch pageviews for Juan Sebastián
# Failed to fetch pageviews for Rambow
# Failed to fetch pageviews for Dei V
# Failed to fetch pageviews for Hanceford Magapatona
# Failed to fetch pageviews for Q124632981
# Failed to fetch pageviews for Flor Pileña
# Failed to fetch pageviews for Dolinau Maksim
# Failed to fetch pageviews for Ntounghchi Kamtchoua Armand Noël
# Failed to fetch pageviews for Mimy Succar
# Failed to fetch pageviews for Brando Bryant
# Failed to fetch pageviews for Q118976845
# Failed to fetch pageviews for Hans-Eckardt Wenzel
# Failed to fetch pageviews for Lion Izmaylov
# Failed to fetch pageviews for Elena Pogrebizhskaia
# Failed to fetch pageviews for Aurélie Saada
# Failed to fetch pageviews for Hana Goldberg
# No views data found for Kåre Virud
# Failed to fetch pageviews for Semadar Shir
# Failed to fetch pageviews for Nizam DRedd
# Failed to fetch pageviews for Fred Espel
# Failed to fetch pageviews for Hans Liberg
# Failed to fetch pageviews for Jorge Fernando
# Failed to fetch pageviews for Igor Chumichkin
# Failed to fetch pageviews for Mkrtich Sudzhian
# Failed to fetch pageviews for James Deano
# Failed to fetch pageviews for Tomasz Działowy
# No views data found for Zwangere Guy
# Failed to fetch pageviews for SlinCraze
# No views data found for MC Soffia
# Failed to fetch pageviews for Eunique
# Failed to fetch pageviews for Jelassi
# Failed to fetch pageviews for Emil Cerda
# Failed to fetch pageviews for Dima Maslennikov
# Failed to fetch pageviews for Eric Mc
# Failed to fetch pageviews for Ghettovi
# Failed to fetch pageviews for Yaovi Kheteti
# 4921 articles found with views data, out of the 5367 in the list

# %%
# How to handle AC/DC?
name='AC/DC'
total_views_2023 = 0

headers = {'User-Agent': 'YourAppName/1.0 (your-email@example.com)'}

# %2F is the url encoding for the character '/'
pageviews_url = "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia/all-access/user/AC%2FDC/monthly/20230101/20231231"

response_pageviews = requests.get(pageviews_url, headers=headers)
if response_pageviews.status_code == 200:
    pageviews_data = response_pageviews.json().get('items', [])

    for item in pageviews_data:
        total_views_2023 += item.get('views', 0)

    if total_views_2023 > 0:
        #names_2023_visits.append({"name": name, "2023_visits": total_views_2023})
        print(f'{name}, {total_views_2023}')
    else:
        print(f"No views data found for {name}")
else:
    print(f"Failed to fetch pageviews for {name}")
# Out:
# AC/DC, 2565212

# %%
names_visits_df=pd.concat([names_visits_df, pd.DataFrame({'name': 'AC/DC', '2023_visits': 2565212}, index=[len(names_visits_df)+2])])

# %%
names_visits_df[names_visits_df['name']=='AC/DC']
# Out:
#        name 2023_visits
# 4921  AC/DC     2565212

# %%
names_visits_df.sort_values(by='2023_visits', ascending=False, inplace=True)
names_visits_df.head(10)
# Out:
#               name 2023_visits
# 0     Taylor Swift    22030018
# 1     XXXTentacion    20104479
# 2       Alia Bhatt    12669342
# 3      Tina Turner    11590403
# 4     Keanu Reeves     9916477
# 5          Rihanna     9885357
# 6     Bruce Willis     9468530
# 7  Michael Jackson     9129164
# 8     Ryan Gosling     8766941
# 9     Selena Gomez     7550367

# %%
names_visits_df.drop_duplicates(inplace=True)

# %%
top_2023_visits_df=names_visits_df[0:1000]
top_2023_visits_df
# Out:
#                 name  2023_visits
# 0       Taylor Swift     22030018
# 1       XXXTentacion     20104479
# 2         Alia Bhatt     12669342
# 3        Tina Turner     11590403
# 4       Keanu Reeves      9916477
# ..               ...          ...
# 995    Crowded House       348751
# 996            Hwasa       348549
# 997      CeCe Winans       348064
# 998  Devi Sri Prasad       347937
# 999        Neil Finn       346864
#
# [1000 rows x 2 columns]

# %%
top_2023_visits_df.to_csv('top_visited_2023.csv', index=False)
