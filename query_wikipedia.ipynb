# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim
from google.colab import files
import pandas as pd
import requests
import time
import wikipediaapi
pip install SPARQLWrapper
pip install geopy
pip install wikipedia-api

# %% [markdown]
# ### Installation and Import of SPARQLWrapper Library
# This section installs `SPARQLWrapper` to enable querying RDF databases using SPARQL directly from Python.

# %%
pip install SPARQLWrapper
# Out:
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1 (from SPARQLWrapper)
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 9.5 MB/s eta 0:00:00
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=6.1.1->SPARQLWrapper)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Installing collected packages: isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 isodate-0.6.1 rdflib-7.0.0

# %% [markdown]
# ### Fetching Data Using SPARQL
# This function queries the Wikidata endpoint to retrieve birthplaces of singers using SPARQL, demonstrating how to interact with semantic web data.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def get_singers_birthplaces():
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    query = """
    SELECT ?personLabel ?birthplaceLabel WHERE {
      # ?person wdt:P106 wd:Q177220;       # Occupation singer
              wdt:P19 ?birthplace.      # Place of birth
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
    }
    LIMIT 100
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    singers = []
    for result in results["results"]["bindings"]:
        person_name = result["personLabel"]["value"]
        birthplace = result["birthplaceLabel"]["value"]
        singers.append(f"{person_name}: Born in {birthplace}")
    return singers

# Fetch and print the list of singers and their birthplaces
singers_list = get_singers_birthplaces()
for singer in singers_list:
    print(singer)
# Out:
# Eric Saade: Born in Kattarp
# Eldar Qasımov: Born in Baku
# Nigar Jamal: Born in Baku
# Inna: Born in Mangalia
# Beth Ditto: Born in Searcy
# Willy Moon: Born in Wellington
# Moby: Born in Harlem
# Hank Mizell: Born in Daytona Beach
# Pharrell Williams: Born in Virginia Beach
# Phoebe Cates-Kline: Born in Manhattan
# Mac DeMarco: Born in Duncan
# Sharon Van Etten: Born in Belleville
# Terry Callier: Born in Chicago
# Mats Levén: Born in Gothenburg
# Ville Kantee: Born in Joutseno
# Lil Wayne: Born in New Orleans
# Freddie Mercury: Born in Zanzibar City
# Brian May: Born in Hampton
# Roger Taylor: Born in Dersingham
# Amy Macdonald: Born in Bishopbriggs
# Kanye West: Born in Atlanta
# William Shatner: Born in Notre-Dame-de-Grâce
# Clive Sarstedt: Born in Ajmer
# Robert Mitchum: Born in Bridgeport
# Andy Lau: Born in Tai Po
# Jacky Cheung: Born in British Hong Kong
# Daniel Boemle: Born in Bern
# Leon Lai: Born in Beijing
# Matti Nykänen: Born in Jyväskylä
# Aaron Kwok: Born in Hong Kong
# Vasco Rossi: Born in Zocca
# Claudio Sanchez: Born in Suffern
# Kotono Mitsuishi: Born in Toda
# Tablo: Born in Seoul
# Eva Simons: Born in Amsterdam
# Rebecca Black: Born in Irvine
# Jessie J: Born in Chadwell Heath
# Wolfram von Eschenbach: Born in Wolframs-Eschenbach
# Ryan Newman: Born in Manhattan Beach
# Jan Delay: Born in Hamburg
# Alesha Dixon: Born in Welwyn Garden City
# Mike Shinoda: Born in Panorama City
# Mark Wakefield: Born in United States of America
# James Euringer: Born in New York City
# Maya Angelou: Born in St. Louis
# Hans Sachs: Born in Nuremberg
# DJ Ötzi: Born in St. Johann in Tirol
# Victoria Beckham: Born in Harlow
# Geri Horner: Born in Watford General Hospital
# Lady Gaga: Born in Lenox Hill Hospital
# IU: Born in Songjeong-dong
# Psy: Born in Gangnam District
# Joe Pesci: Born in Newark
# Franzl Lang: Born in Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln
# Cro: Born in Mutlangen
# Schné: Born in Bad Oldesloe
# Alexander Knappe: Born in Cottbus
# DJ Laz: Born in Miami
# John Farnham: Born in Dagenham
# Ismael Serrano: Born in Madrid
# Huh Gak: Born in Incheon
# Daniela Katzenberger: Born in Ludwigshafen
# Adele: Born in Tottenham
# Roberto Benigni: Born in Castiglion Fiorentino
# Tim Minchin: Born in Northampton
# Selena: Born in Lake Jackson
# Kim J. Henriksen: Born in Copenhagen
# Jean Gabin: Born in 9th arrondissement of Paris
# Andrew Garfield: Born in Los Angeles
# Johnny Ruffo: Born in Balcatta
# Amanda Somerville: Born in Flushing
# Juju: Born in Kyoto Prefecture
# Taryll Jackson: Born in Los Angeles
# John Barrowman: Born in Glasgow
# Abz Love: Born in London Borough of Enfield
# Lee Hi: Born in Bucheon
# Luísa Sobral: Born in Lisbon
# Ilya Oleynikov: Born in Chișinău
# Franco Battiato: Born in Giarre-Riposto
# Angelo Branduardi: Born in Cuggiono
# Ville Valo: Born in Helsinki
# Marcus Mumford: Born in Anaheim
# Martha Reeves: Born in Eufaula
# Linde Lindström: Born in Klaukkala
# Tomasz Wróblewski: Born in Warsaw
# Richard Bona: Born in Minta
# Kastro Zizo: Born in Tirana
# Célia Lawson: Born in Angola
# Carlos PenaVega: Born in Columbia
# James Maslow: Born in New York City
# Chris Wood: Born in Birmingham
# Logan Henderson: Born in North Richland Hills
# Patryk Dominik Sztyber: Born in Opoczno
# Ariel Winter: Born in Fairfax
# Lisa Zane: Born in Chicago
# Marc Anthony: Born in New York City
# Yuri Stoyanov: Born in Odesa
# Lionel Richie: Born in Tuskegee
# Daiki Arioka: Born in Chiba
# Poopy: Born in Madagascar

# %% [markdown]
# ### Direct HTTP Requests for Artist Information
# Using direct HTTP requests to retrieve artist birthplaces from Wikidata, this shows a manual approach to sending queries and processing responses.

# %%
import requests

def fetch_artist_birthplaces(artist_names, limit=10):
    """Fetches birthplaces for a list of artist names using direct HTTP requests to the Wikidata endpoint."""
    wikidata_endpoint = "https://query.wikidata.org/sparql"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
        'Accept': 'application/sparql-results+json'
    }
    artist_birthplaces = []

    for artist_name in artist_names[:limit]:  # Limiting to a few artists for demonstration
        query = f"""
        SELECT ?artistLabel ?birthplaceLabel WHERE {{
          # ?artist wdt:P106 wd:Q177220;  # Occupation singer
                  rdfs:label "{artist_name}"@en;
                  wdt:P19 ?birthplace.
          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
        }}
        LIMIT 1
        """
        response = requests.get(wikidata_endpoint, headers=headers, params={'query': query, 'format': 'json'})
        data = response.json()

        if data["results"]["bindings"]:
            for result in data["results"]["bindings"]:
                birthplace = result["birthplaceLabel"]["value"] if "birthplaceLabel" in result else "Unknown"
                artist_birthplaces.append((artist_name, birthplace))
        else:
            artist_birthplaces.append((artist_name, "Birthplace not found"))

    return artist_birthplaces

# Test fetching birthplaces for a small subset of artists
sample_artists = ['Taylor Swift', 'Michael Jackson', 'Rihanna']  # Example artist names
artist_birthplaces = fetch_artist_birthplaces(sample_artists)
artist_birthplaces
# Out:
# [('Taylor Swift', 'West Reading'),
#  ('Michael Jackson', 'Gary'),
#  ('Rihanna', 'Saint Michael')]

# %% [markdown]
# ### Direct HTTP Requests for Artist Information
# Using direct HTTP requests to retrieve artist birthplaces from Wikidata, this shows a manual approach to sending queries and processing responses.

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/NUMBER_of_views")
df
# Out:
#         Unnamed: 0          article        date  views
# 0                0     Taylor Swift  2023-01-01  29705
# 1                1     Taylor Swift  2023-01-02  25766
# 2                2     Taylor Swift  2023-01-03  24682
# 3                3     Taylor Swift  2023-01-04  21214
# 4                4     Taylor Swift  2023-01-05  22873
# ...            ...              ...         ...    ...
# 356922      356922  Devi Sri Prasad  2023-12-27    588
# 356923      356923  Devi Sri Prasad  2023-12-28    636
# 356924      356924  Devi Sri Prasad  2023-12-29    706
# 356925      356925  Devi Sri Prasad  2023-12-30    686
# 356926      356926  Devi Sri Prasad  2023-12-31    720
#
# [356927 rows x 4 columns]

# %% [markdown]
# ### Direct HTTP Requests for Artist Information
# Using direct HTTP requests to retrieve artist birthplaces from Wikidata, this shows a manual approach to sending queries and processing responses.

# %%
import requests
import pandas as pd

artists_data = df["article"]
unique_artists = artists_data.unique()  # Assuming 'article' is the column with artist names

def fetch_artist_birthplaces(artist_names):
    """Fetches birthplaces for all artist names in the DataFrame using direct HTTP requests to the Wikidata endpoint."""
    wikidata_endpoint = "https://query.wikidata.org/sparql"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
        'Accept': 'application/sparql-results+json'
    }
    artist_birthplaces = []

    for artist_name in artist_names:  # Process all artists in the list
        query = f"""
        SELECT ?artistLabel ?birthplaceLabel WHERE {{
          # ?artist wdt:P106 wd:Q177220;  # Occupation singer
                  rdfs:label "{artist_name}"@en;
                  wdt:P19 ?birthplace.
          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
        }}
        LIMIT 1
        """
        response = requests.get(wikidata_endpoint, headers=headers, params={'query': query, 'format': 'json'})
        data = response.json()

        if data["results"]["bindings"]:
            for result in data["results"]["bindings"]:
                birthplace = result["birthplaceLabel"]["value"] if "birthplaceLabel" in result else "Unknown"
                artist_birthplaces.append((artist_name, birthplace))
        else:
            artist_birthplaces.append((artist_name, "Birthplace not found"))

    return artist_birthplaces

# Fetching birthplaces for all artists
artist_birthplaces = fetch_artist_birthplaces(unique_artists)
artist_birthplaces
# Out:
# [('Taylor Swift', 'West Reading'),
#  ('XXXTentacion', 'Plantation'),
#  ('Alia Bhatt', 'India'),
#  ('Tina Turner', 'Brownsville'),
#  ('Keanu Reeves', 'Beirut'),
#  ('Rihanna', 'Saint Michael'),
#  ('Bruce Willis', 'Idar-Oberstein'),
#  ('Michael Jackson', 'Gary'),
#  ('Ryan Gosling', 'London'),
#  ('Selena Gomez', 'Grand Prairie'),
#  ('Whitney Houston', 'Newark'),
#  ('Miley Cyrus', 'Nashville'),
#  ('Scarlett Johansson', 'Manhattan'),
#  ('Hannah Waddingham', 'Wandsworth'),
#  ('Eminem', 'St. Joseph'),
#  ('Kanye West', 'Atlanta'),
#  ('Florence Pugh', 'Oxford'),
#  ('Priyanka Chopra', 'Jamshedpur'),
#  ('Tupac Shakur', 'Birthplace not found'),
#  ('Freddie Mercury', 'Zanzibar City'),
#  ('George Michael', 'East Finchley'),
#  ('Zendaya', 'Oakland'),
#  ('Johnny Depp', 'Birthplace not found'),
#  ('Madonna', 'Bay City'),
#  ('Cher', 'El Centro'),
#  ('Adam Sandler', 'Brooklyn'),
#  ('Dua Lipa', 'Westminster'),
#  ('Salma Hayek', 'Coatzacoalcos'),
#  ('Robert Downey Jr.', 'Manhattan'),
#  ("Shaquille O'Neal", 'Newark'),
#  ('Bradley Cooper', 'Philadelphia'),
#  ('Olivia Rodrigo', 'Murrieta'),
#  ('Britney Spears', 'McComb'),
#  ('Mark Wahlberg', 'Birthplace not found'),
#  ('Shakira', 'Barranquilla'),
#  ('Lady Gaga', 'Lenox Hill Hospital'),
#  ('David Bowie', 'Brixton'),
#  ('John Cena', 'Birthplace not found'),
#  ('Salman Khan', 'Indore'),
#  ('Elton John', 'Pinner'),
#  ('Raquel Welch', 'Chicago'),
#  ('Jimmy Buffett', 'Pascagoula'),
#  ('BTS', 'Birthplace not found'),
#  ('The Beatles', 'Birthplace not found'),
#  ('Austin Butler', 'Anaheim'),
#  ('Joaquin Phoenix', 'Río Piedras'),
#  ('Katy Perry', 'Birthplace not found'),
#  ('Kate Winslet', 'Reading'),
#  ('Billie Eilish', 'Los Angeles'),
#  ('Ezra Miller', 'Wyckoff'),
#  ('John Travolta', 'Englewood'),
#  ('The Weeknd', 'Toronto'),
#  ('Jennifer Connelly', 'Cairo'),
#  ('Lewis Capaldi', 'Glasgow'),
#  ('Nicole Kidman', 'Honolulu'),
#  ('Gwyneth Paltrow', 'Los Angeles'),
#  ('Ed Sheeran', 'Halifax'),
#  ('Will Smith', 'Philadelphia'),
#  ('Victoria Beckham', 'Harlow'),
#  ('Snoop Dogg', 'Long Beach'),
#  ('Jackie Chan', 'Victoria Peak'),
#  ('Jamie Foxx', 'Terrell'),
#  ('Anne Hathaway', 'Brooklyn'),
#  ('Bad Bunny', 'Vega Baja'),
#  ('Brie Larson', 'Sacramento'),
#  ('Daniel Radcliffe', 'Hammersmith'),
#  ('Paris Hilton', 'New York City'),
#  ('Fleetwood Mac', 'Birthplace not found'),
#  ('Nick Cannon', 'Birthplace not found'),
#  ('Stevie Nicks', 'Phoenix'),
#  ('Mariah Carey', 'Huntington'),
#  ('Russell Brand', 'Grays'),
#  ('Europe', 'Birthplace not found'),
#  ('Bob Marley', 'Gullegem'),
#  ('Doja Cat', 'Birthplace not found'),
#  ('Amy Winehouse', 'Birthplace not found'),
#  ('Eddie Murphy', 'Brooklyn'),
#  ('Post Malone', 'Syracuse'),
#  ('Nicki Minaj', 'Saint James'),
#  ('Mary Elizabeth Winstead', 'Rocky Mount'),
#  ('Kim Petras', 'Bonn'),
#  ('Justin Timberlake', 'Memphis'),
#  ('Ozzy Osbourne', 'Marston Green'),
#  ('Shia LaBeouf', 'Birthplace not found'),
#  ('Zooey Deschanel', 'Los Angeles'),
#  ('Suzanne Somers', 'San Bruno'),
#  ('Jeff Beck', 'Birthplace not found'),
#  ('Brenda Song', 'Carmichael'),
#  ('River Phoenix', 'Birthplace not found'),
#  ('Catherine Zeta-Jones', 'Swansea'),
#  ('Mick Jagger', 'Dartford'),
#  ('Jared Leto', 'Bossier City'),
#  ('Bob Dylan', 'Duluth'),
#  ('Barbra Streisand', 'Brooklyn'),
#  ('Hailee Steinfeld', 'Tarzana'),
#  ('Adele', 'Tottenham'),
#  ('Niall Horan', 'Mullingar'),
#  ('Sam Smith', 'London'),
#  ('Shania Twain', 'Windsor'),
#  ('Phil Collins', 'Putney Hospital'),
#  ('Hugh Jackman', 'Sydney'),
#  ('Patrick Swayze', 'Houston'),
#  ('Zayn Malik', 'Bradford'),
#  ('Jack Black', 'Santa Monica'),
#  ('Julia Louis-Dreyfus', 'Manhattan'),
#  ('Tim Curry', 'Grappenhall'),
#  ('ZoÃ« Kravitz', 'Birthplace not found'),
#  ('Carrie Fisher', 'United States of America'),
#  ('Anna Kendrick', 'Portland'),
#  ('Jay-Z', 'Birthplace not found'),
#  ('The Notorious B.I.G.', 'Birthplace not found'),
#  ('Rajinikanth', 'Bengaluru'),
#  ('Amitabh Bachchan', 'Prayagraj'),
#  ('Robert Pattinson', 'London'),
#  ('Gwen Stefani', 'Fullerton'),
#  ('The Rolling Stones', 'Birthplace not found'),
#  ('Travis Scott', 'Houston'),
#  ('Zac Efron', 'San Luis Obispo'),
#  ('Rita Ora', 'Pristina'),
#  ('Metallica', 'Birthplace not found'),
#  ('Jesse Plemons', 'Dallas'),
#  ('Robbie Williams', 'Stoke-on-Trent'),
#  ('Kate Hudson', 'Los Angeles'),
#  ('Cardi B', 'Birthplace not found'),
#  ('Michael Keaton', 'Coraopolis'),
#  ('Dakota Fanning', 'Conyers'),
#  ('Mayim Bialik', 'San Diego'),
#  ('Matthew Broderick', 'Manhattan'),
#  ('Kylie Minogue', 'Melbourne'),
#  ('Awkwafina', 'New York City'),
#  ('Joe Alwyn', 'Birthplace not found'),
#  ('Chicago', 'Birthplace not found'),
#  ('Lainey Wilson', 'Baskin'),
#  ('Amanda Seyfried', 'Allentown'),
#  ('Aaliyah', 'Brooklyn'),
#  ('Steven Seagal', 'Lansing'),
#  ('Avril Lavigne', 'Belleville'),
#  ('Dave Grohl', 'Warren'),
#  ('Kirsten Dunst', 'Point Pleasant'),
#  ('50 Cent', 'Birthplace not found'),
#  ('Sally Field', 'Pasadena'),
#  ('Jada Pinkett Smith', 'Baltimore'),
#  ('Gillian Anderson', 'Chicago'),
#  ('Ewan McGregor', 'Perth'),
#  ('Antonio Banderas', 'Málaga'),
#  ('Bruce Springsteen', 'Long Branch'),
#  ('Lily James', 'Esher'),
#  ('Sean Combs', 'Harlem'),
#  ('Lionel Richie', 'Tuskegee'),
#  ('Ice Cube', 'Birthplace not found'),
#  ('Andrew Garfield', 'Los Angeles'),
#  ('Angela Bassett', 'New York City'),
#  ('Michelle Pfeiffer', 'Santa Ana'),
#  ('Russell Crowe', 'Wellington'),
#  ('Steve Harvey', 'Welch'),
#  ('Selena', 'Lake Jackson'),
#  ('Kelly Clarkson', 'Fort Worth'),
#  ('Chris Brown', 'Tappahannock'),
#  ('R. Kelly', 'Chicago'),
#  ('Lynyrd Skynyrd', 'Birthplace not found'),
#  ('Goldie Hawn', 'Washington, D.C.'),
#  ('Jimi Hendrix', 'Birthplace not found'),
#  ('Tyler Perry', 'Birthplace not found'),
#  ('ABBA', 'Birthplace not found'),
#  ('Bruno Mars', 'Honolulu'),
#  ('Olivia Newton-John', 'Cambridge'),
#  ('Kiefer Sutherland', 'Birthplace not found'),
#  ('Jack Antonoff', 'Bergenfield'),
#  ('Grimes', 'Vancouver'),
#  ('Avicii', 'Stockholm'),
#  ('Tracy Chapman', 'Cleveland'),
#  ('Yoko Ono', 'Tokyo'),
#  ('Jane Birkin', 'London'),
#  ('Led Zeppelin', 'Birthplace not found'),
#  ('Rod Stewart', 'London'),
#  ('Joey King', 'Los Angeles'),
#  ('Keke Palmer', 'Harvey'),
#  ('Eric Clapton', 'Ripley'),
#  ('N. T. Rama Rao Jr.', 'Hyderabad'),
#  ('Bee Gees', 'Birthplace not found'),
#  ('Joe Pesci', 'Newark'),
#  ('Lizzo', 'Detroit'),
#  ('Kris Kristofferson', 'Brownsville'),
#  ('Depeche Mode', 'Birthplace not found'),
#  ("Guns N' Roses", 'Birthplace not found'),
#  ('Hayden Panettiere', 'Palisades'),
#  ('Amy Adams', 'Aviano'),
#  ('Lenny Kravitz', 'New York City'),
#  ('Kristen Bell', 'Huntington Woods'),
#  ('Donald Glover', 'Edwards Air Force Base'),
#  ('David Crosby', 'Los Angeles'),
#  ('Taron Egerton', 'Birkenhead'),
#  ('Stevie Wonder', 'Saginaw'),
#  ('Dr. Dre', 'Birthplace not found'),
#  ('Ranveer Singh', 'Birthplace not found'),
#  ('Kamal Haasan', 'Paramakudi'),
#  ('Steven Yeun', 'Seoul'),
#  ('Billy Joel', 'New York City'),
#  ('Red Hot Chili Peppers', 'Birthplace not found'),
#  ('Whoopi Goldberg', 'New York City'),
#  ('Janet Jackson', 'Gary'),
#  ('Seth MacFarlane', 'Kent'),
#  ('Viggo Mortensen', 'Watertown'),
#  ('Keerthy Suresh', 'Chennai'),
#  ('John Denver', 'Roswell'),
#  ('Zachary Levi', 'Lake Charles'),
#  ('Jon Bon Jovi', 'Perth Amboy'),
#  ('Linda Ronstadt', 'Tucson'),
#  ('Demi Lovato', 'Albuquerque'),
#  ("Catherine O'Hara", 'Toronto'),
#  ('Jack Harlow', 'Louisville'),
#  ('KSI', 'Birthplace not found'),
#  ('Alanis Morissette', 'Ottawa'),
#  ('Vanessa Paradis', 'Saint-Maur-des-Fossés'),
#  ('Chevy Chase', 'Manhattan'),
#  ('Megan Thee Stallion', 'San Antonio'),
#  ('Bill Cosby', 'Philadelphia'),
#  ('Kendrick Lamar', 'Compton'),
#  ('Meghan Trainor', 'Nantucket'),
#  ('Don Johnson', 'Flat Creek'),
#  ('Maya Rudolph', 'Gainesville'),
#  ('Allu Arjun', 'Chennai'),
#  ('Jisoo', 'Gunpo'),
#  ('Shirley Temple', 'Santa Monica'),
#  ('Steven Tyler', 'New York City'),
#  ('Sanjay Dutt', 'Mumbai'),
#  ('Tom Petty', 'Gainesville'),
#  ('Billy Bob Thornton', 'Hot Springs'),
#  ('Toni Collette', 'Glebe'),
#  ('Tammy Wynette', 'Itawamba County'),
#  ('Cat Stevens', 'Marylebone'),
#  ('Janis Joplin', 'Port Arthur'),
#  ('Danny Elfman', 'Los Angeles'),
#  ('Leighton Meester', 'Fort Worth'),
#  ('Ian McShane', 'Blackburn'),
#  ('Bella Thorne', 'Pembroke Pines'),
#  ('Hugh Laurie', 'Blackbird Leys'),
#  ('Martin Short', 'Ontario'),
#  ('Ann-Margret', 'Valsjöbyn'),
#  ('Sidhu Moose Wala', 'Moosa'),
#  ('Lin-Manuel Miranda', 'Manhattan'),
#  ('Idina Menzel', 'Manhattan'),
#  ('John Mayer', 'Bridgeport'),
#  ('David Foster', 'Birthplace not found'),
#  ('Alice Cooper', 'Detroit'),
#  ('Lauryn Hill', 'Newark'),
#  ('Queen Latifah', 'Newark'),
#  ('Marc Anthony', 'New York City'),
#  ('Barry Manilow', 'Brooklyn'),
#  ('Damian Lillard', 'Birthplace not found'),
#  ('Peso Pluma', 'Zapopan'),
#  ('Brigitte Nielsen', 'Rødovre'),
#  ('Elisabeth Shue', 'Wilmington'),
#  ('David Lynch', 'St. Louis'),
#  ('Katey Sagal', 'Hollywood'),
#  ('RuPaul', 'San Diego'),
#  ('Dove Cameron', 'Bainbridge Island'),
#  ('Neil Young', 'Toronto'),
#  ('Sarah Silverman', 'Bedford'),
#  ('Robert Plant', 'West Bromwich'),
#  ('The Beach Boys', 'Birthplace not found'),
#  ('Hayley Williams', 'Meridian'),
#  ('Tim McGraw', 'Delhi'),
#  ('Peter Gabriel', 'Chobham'),
#  ('Tessa Thompson', 'Los Angeles'),
#  ('Andy Samberg', 'Berkeley'),
#  ('Neil Patrick Harris', 'Albuquerque'),
#  ('Joni Mitchell', 'Fort Macleod'),
#  ('Brandi Carlile', 'Ravensdale'),
#  ('Donna Summer', 'Boston'),
#  ('John Goodman', 'Affton'),
#  ('Hans Zimmer', 'Birthplace not found'),
#  ('Billy Ray Cyrus', 'Birthplace not found'),
#  ('Rita Wilson', 'Hollywood'),
#  ('Kim Basinger', 'Athens'),
#  ('Mandy Moore', 'Nashua'),
#  ('David Byrne', 'Dumbarton'),
#  ('John Stamos', 'Cypress'),
#  ('Neil Diamond', 'Brooklyn'),
#  ('Golshifteh Farahani', 'Tehran'),
#  ('Andrea Bocelli', 'Birthplace not found'),
#  ('Pawan Kalyan', 'Bapatla'),
#  ('Chris Farley', 'Madison'),
#  ('Paul Bettany', 'Birthplace not found'),
#  ("Beverly D'Angelo", 'Columbus'),
#  ('Backstreet Boys', 'Birthplace not found'),
#  ('BjÃ¶rk', 'Birthplace not found'),
#  ('Kid Rock', 'Romeo'),
#  ('The Chicks', 'Birthplace not found'),
#  ('Kristin Chenoweth', 'Broken Arrow'),
#  ('Dan Aykroyd', 'Ottawa'),
#  ('Blake Shelton', 'Ada'),
#  ('Jonathan Groff', 'Lancaster'),
#  ('Brian May', 'Hampton'),
#  ('Taraji P. Henson', 'Washington, D.C.'),
#  ('Camila Cabello', 'Cojímar'),
#  ('A. R. Rahman', 'Chennai'),
#  ('Jonas Brothers', 'Birthplace not found'),
#  ('Beastie Boys', 'Birthplace not found'),
#  ('Allen Iverson', 'Birthplace not found'),
#  ('Chris Stapleton', 'Lexington'),
#  ('Alyssa Milano', 'Bensonhurst'),
#  ('Ice-T', 'Birthplace not found'),
#  ('Creedence Clearwater Revival', 'Birthplace not found'),
#  ('Bono', 'Birthplace not found'),
#  ('Bebe Rexha', 'Brooklyn'),
#  ('Andrew Lloyd Webber', 'Birthplace not found'),
#  ('Manny Pacquiao', 'Kibawe'),
#  ('Morrissey', 'Davyhulme'),
#  ('Alicia Keys', "Hell's Kitchen"),
#  ('Imagine Dragons', 'Birthplace not found'),
#  ('Brian Wilson', 'Inglewood'),
#  ('Paula Abdul', 'San Fernando'),
#  ('Minnie Driver', 'Marylebone'),
#  ('Ariana DeBose', 'Wilmington'),
#  ('Cyndi Lauper', 'New York City'),
#  ('Lee Majors', 'Wyandotte'),
#  ('Steven Van Zandt', 'Winthrop'),
#  ('Patrick Wilson', 'Norfolk'),
#  ('Barbados', 'Birthplace not found'),
#  ('Molly Ringwald', 'Roseville'),
#  ('LL Cool J', 'Queens'),
#  ('Meat Loaf', 'Dallas'),
#  ('Big Bang', 'Birthplace not found'),
#  ('U2', 'Birthplace not found'),
#  ('Pharrell Williams', 'Virginia Beach'),
#  ("Vincent D'Onofrio", 'Brooklyn'),
#  ('Jason Alexander', 'Newark'),
#  ('Arctic Monkeys', 'Birthplace not found'),
#  ('Naya Rivera', 'Valencia'),
#  ('Frank Ocean', 'Long Beach'),
#  ('John Legend', 'Springfield'),
#  ('Tory Lanez', 'Brampton'),
#  ('MÃ¥neskin', 'Birthplace not found'),
#  ('Nelly', 'Austin'),
#  ('Lana Rhoades', 'Chicago'),
#  ('Nancy Sinatra', 'Jersey City'),
#  ('Carrie Underwood', 'Muskogee'),
#  ('Krysten Ritter', 'Birthplace not found'),
#  ('Megan Mullally', 'Los Angeles'),
#  ('Wesley Snipes', 'Orlando'),
#  ('Eugene Levy', 'Birthplace not found'),
#  ('Michael Richards', 'Culver City'),
#  ('Becky G', 'Inglewood'),
#  ('Iron Maiden', 'Birthplace not found'),
#  ('Penny Marshall', 'The Bronx'),
#  ('Chaz Bono', 'Los Angeles'),
#  ('Mike Myers', 'Scarborough'),
#  ('Radiohead', 'Birthplace not found'),
#  ('Grace Jones', 'Spanish Town'),
#  ('Iggy Azalea', 'Sydney'),
#  ('Coolio', 'Monessen'),
#  ('Duran Duran', 'Birthplace not found'),
#  ('Miranda Cosgrove', 'Los Angeles'),
#  ('Vanessa Williams', 'The Bronx'),
#  ('Daisy Ridley', 'London'),
#  ('Kid Cudi', 'Cleveland'),
#  ('Mohanlal', 'Elanthoor'),
#  ('The Cure', 'Birthplace not found'),
#  ('Lil Nas X', 'Lithia Springs'),
#  ('Shelley Duvall', 'Fort Worth'),
#  ('Damon Albarn', 'London'),
#  ('Charlotte Gainsbourg', 'Marylebone'),
#  ('ZZ Top', 'Birthplace not found'),
#  ('RZA', 'Birthplace not found'),
#  ('Rammstein', 'Birthplace not found'),
#  ('Connie Britton', 'Boston'),
#  ('Boney M.', 'Birthplace not found'),
#  ('Jessie Buckley', 'Killarney'),
#  ('Adam Levine', 'Los Angeles'),
#  ('Daveed Diggs', 'Birthplace not found'),
#  ('Keith Urban', 'Whangārei'),
#  ('Sara Ramirez', 'Mazatlán'),
#  ('Joe Walsh', 'Wichita'),
#  ('Sheryl Crow', 'Kennett'),
#  ('Tom Felton', 'Epsom'),
#  ('Greta Van Fleet', 'Birthplace not found'),
#  ('Abigail Breslin', 'New York City'),
#  ('Jenny Slate', 'Milton'),
#  ('Michael McKean', 'Birthplace not found'),
#  ('Fall Out Boy', 'Birthplace not found'),
#  ('Scandinavia', 'Birthplace not found'),
#  ('Ludacris', 'Birthplace not found'),
#  ('Kate Bush', 'Bexleyheath'),
#  ('Iggy Pop', 'Muskegon'),
#  ('Shawn Mendes', 'Pickering'),
#  ('H.E.R.', 'Vallejo'),
#  ('Bo Burnham', 'Birthplace not found'),
#  ('Garth Brooks', 'Tulsa'),
#  ('Alabama', 'Birthplace not found'),
#  ('Hiroyuki Sanada', 'Shinagawa-ku'),
#  ('The Mamas & the Papas', 'Birthplace not found'),
#  ('Jon Batiste', 'Kenner'),
#  ('Linda McCartney', 'Scarsdale'),
#  ('Don Henley', 'Gilmer'),
#  ('Van Halen', 'Birthplace not found'),
#  ('Maya Angelou', 'St. Louis'),
#  ('Bryan Adams', 'Kingston'),
#  ('Kesha', 'Los Angeles'),
#  ('Asia Argento', 'Rome'),
#  ('Annie Lennox', 'Aberdeen'),
#  ('James Taylor', 'Boston'),
#  ('Jack White', 'Cologne'),
#  ('Keith David', 'New York City'),
#  ('Aerosmith', 'Birthplace not found'),
#  ('Faith Hill', 'Ridgeland'),
#  ('Tyler James Williams', 'New York City'),
#  ('Carly Simon', 'The Bronx'),
#  ('Rage Against the Machine', 'Birthplace not found'),
#  ('Nelly Furtado', 'Victoria'),
#  ('Anthony Ramos', 'Brooklyn'),
#  ('Billie Piper', 'Swindon'),
#  ('Jonathan Rhys Meyers', 'Dublin'),
#  ('Alex Borstein', 'Highland Park'),
#  ('Stevie Ray Vaughan', 'Birthplace not found'),
#  ('Jussie Smollett', 'Santa Rosa'),
#  ('Arijit Singh', 'Jiaganj Azimganj'),
#  ('Norah Jones', 'Brooklyn'),
#  ('Sarah Polley', 'Toronto'),
#  ('Ben Platt', 'Los Angeles'),
#  ('LeAnn Rimes', 'Jackson'),
#  ('Daft Punk', 'Birthplace not found'),
#  ('Bon Jovi', 'Birthplace not found'),
#  ('Dianna Agron', 'Savannah'),
#  ('John Mellencamp', 'Seymour'),
#  ('Jason Mraz', 'Mechanicsville'),
#  ('Trey Parker', 'Conifer'),
#  ('Toby Keith', 'Clinton'),
#  ('Israel KamakawiwoÊ»ole', 'Birthplace not found'),
#  ('Patti Smith', 'United States of America'),
#  ('Luther Vandross', 'New York City'),
#  ('Grateful Dead', 'Birthplace not found'),
#  ('Ethan Slater', 'Washington, D.C.'),
#  ('Rob Zombie', 'Haverhill'),
#  ('Drew Carey', 'Cleveland'),
#  ('Shreya Ghoshal', 'Durgapur'),
#  ("Destiny's Child", 'Birthplace not found'),
#  ('Steely Dan', 'Birthplace not found'),
#  ('Mary J. Blige', 'New York City'),
#  ('Arrested Development', 'Birthplace not found'),
#  ('Martha Plimpton', 'New York City'),
#  ('David Gilmour', 'Cambridge'),
#  ('The Band', 'Birthplace not found'),
#  ('Mark Ronson', 'Notting Hill'),
#  ('Randy Travis', 'Birthplace not found'),
#  ('Rajesh Khanna', 'Amritsar'),
#  ('Mandy Patinkin', 'Chicago'),
#  ('Nick Cave', 'Warracknabeal'),
#  ('Chance the Rapper', 'Chicago'),
#  ('Isabela Merced', 'Cleveland'),
#  ('Jessie J', 'Chadwell Heath'),
#  ('Burna Boy', 'Port Harcourt'),
#  ('Danny Glover', 'San Francisco'),
#  ('Mark Knopfler', 'Birthplace not found'),
#  ('Tom Waits', 'Pomona'),
#  ('Cybill Shepherd', 'Memphis'),
#  ('New Kids on the Block', 'Birthplace not found'),
#  ('Keith Carradine', 'San Mateo'),
#  ('Michael BublÃ©', 'Birthplace not found'),
#  ('Sheryl Lee Ralph', 'Waterbury'),
#  ('Tyler Childers', 'Lawrence County'),
#  ('Sissy Spacek', 'Quitman'),
#  ('Wayne Brady', 'Columbus'),
#  ('Willow Smith', 'Los Angeles'),
#  ('Chris Jericho', 'Manhasset'),
#  ('Lou Reed', 'Brookdale University Hospital and Medical Center'),
#  ('The Yardbirds', 'Birthplace not found'),
#  ('George Strait', 'Poteet'),
#  ('Lorde', 'Auckland'),
#  ('Charlie Puth', 'Rumson'),
#  ('Terrence Howard', 'Chicago'),
#  ('Tanya Tucker', 'Seminole'),
#  ('Pentatonix', 'Birthplace not found'),
#  ('Taryn Manning', 'Falls Church'),
#  ('Leslie Odom Jr.', 'Queens'),
#  ('Billy Connolly', 'Glasgow'),
#  ('Dire Straits', 'Birthplace not found'),
#  ('Hank Williams Jr.', 'Shreveport'),
#  ('Missy Elliott', 'Portsmouth'),
#  ('Kane Brown', 'Birthplace not found'),
#  ('RenÃ© AngÃ©lil', 'Birthplace not found'),
#  ('Carlos Santana', 'Autlán de Navarro'),
#  ("Rosie O'Donnell", 'Commack'),
#  ('Billy Crystal', 'New York City'),
#  ('Desi Arnaz', 'Santiago de Cuba'),
#  ('Cailee Spaeny', 'Springfield'),
#  ('Ricky Martin', 'San Juan'),
#  ('Enya', 'Gweedore'),
#  ('Ramones', 'Birthplace not found'),
#  ('Michael Bolton', 'New Haven'),
#  ('Tia Carrere', 'Honolulu'),
#  ('Traveling Wilburys', 'Birthplace not found'),
#  ('Jerry Garcia', 'San Francisco'),
#  ('Jason Derulo', 'Miramar'),
#  ('The Temptations', 'Birthplace not found'),
#  ('The Monkees', 'Birthplace not found'),
#  ('Bette Midler', 'Honolulu'),
#  ('Amandla Stenberg', 'Los Angeles'),
#  ('Glenn Frey', 'Detroit'),
#  ('Beck', 'Los Angeles'),
#  ('The Pogues', 'Birthplace not found'),
#  ('Lynda Carter', 'Phoenix'),
#  ('Wiz Khalifa', 'Minot'),
#  ('Lucy Lawless', 'Mount Albert'),
#  ('David Cross', 'Roswell'),
#  ('David Hasselhoff', 'Baltimore'),
#  ('Kristy McNichol', 'Los Angeles'),
#  ('AnnaSophia Robb', 'Denver'),
#  ('Addison Rae', 'Lafayette'),
#  ('Sufjan Stevens', 'Birthplace not found'),
#  ('Skrillex', 'Birthplace not found'),
#  ('Phylicia Rashad', 'Houston'),
#  ('Bonnie Raitt', 'Burbank'),
#  ('Trent Reznor', 'New Castle'),
#  ('Jane Lynch', 'Evergreen Park'),
#  ('Joanne Whalley', 'Salford'),
#  ('T.I.', 'Birthplace not found'),
#  ('Ayushmann Khurrana', 'Chandigarh'),
#  ('Miranda Lambert', 'Longview'),
#  ('Joy Division', 'Birthplace not found'),
#  ('Riz Ahmed', 'Wembley'),
#  ('MÃ©lanie Laurent', 'Birthplace not found'),
#  ('Bebe Neuwirth', 'Newark'),
#  ('Max Martin', 'Sånga församling'),
#  ('Gregg Allman', 'Saint Thomas Hospital'),
#  ('Alan Jackson', 'Birthplace not found'),
#  ('Amy Irving', 'Palo Alto'),
#  ('Han Hyo-joo', 'Cheongju'),
#  ('Elvis Costello', 'London'),
#  ('The Jackson 5', 'Birthplace not found'),
#  ('Josh Gad', 'Hollywood'),
#  ('Julio Iglesias', 'Madrid'),
#  ('M. M. Keeravani', 'Kovvur'),
#  ('Bob Geldof', 'Dún Laoghaire'),
#  ('Sasha Grey', 'North Highlands'),
#  ('Jay Leno', 'New Rochelle'),
#  ('Jeff Lynne', 'Birthplace not found'),
#  ('Television', 'Birthplace not found'),
#  ('Macklemore', 'Seattle'),
#  ('Chocolate', 'Birthplace not found'),
#  ('Prabhu Deva', 'Mysore'),
#  ('Isaac Hayes', 'Covington'),
#  ('Ne-Yo', 'Camden'),
#  ('Bob Seger', 'Detroit'),
#  ('John Mahoney', 'Blackpool'),
#  ('Farhan Akhtar', 'Mumbai'),
#  ('Todd Rundgren', 'Upper Darby Township'),
#  ('John Deacon', 'Birthplace not found'),
#  ('Lyle Lovett', 'Houston'),
#  ('Brian Eno', 'Woodbridge'),
#  ('Earth', 'Birthplace not found'),
#  ('Luis Enrique', 'Nicaragua'),
#  ('Vince Gill', 'Birthplace not found'),
#  ('Lele Pons', 'Caracas'),
#  ('Jason Isbell', 'Green Hill'),
#  ('Kelly Rowland', 'Atlanta'),
#  ('The Byrds', 'Birthplace not found'),
#  ('Cynthia Erivo', 'Stockwell'),
#  ('The Kid Laroi', 'Birthplace not found'),
#  ('Dolphin', 'Moscow'),
#  ('Frank Stallone', 'New York City'),
#  ('Shabana Azmi', 'Azamgarh'),
#  ('Freema Agyeman', 'London'),
#  ('Serj Tankian', 'Lebanon'),
#  ('Pete Townshend', 'London'),
#  ('Chaka Khan', 'Chicago'),
#  ("Finneas O'Connell", 'Los Angeles'),
#  ('Peter Frampton', 'Birthplace not found'),
#  ('Diplo', 'Birthplace not found'),
#  ('Brandy', 'McComb'),
#  ('Kenny Chesney', 'Birthplace not found'),
#  ('Joe Cocker', 'Sheffield'),
#  ('Laura Bailey', 'Biloxi'),
#  ('Alan Thicke', 'Kirkland Lake'),
#  ('Gilda Radner', 'Detroit'),
#  ('Dingo', 'Birthplace not found'),
#  ('Jackson Browne', 'Heidelberg'),
#  ('Electric Light Orchestra', 'Birthplace not found'),
#  ('Bill Wyman', 'Birthplace not found'),
#  ('Chyler Leigh', 'Charlotte'),
#  ('Derek Hough', 'Salt Lake City'),
#  ('Vanilla Ice', 'Dallas'),
#  ('Toni Braxton', 'Severn'),
#  ('Nithya Menen', 'Bengaluru'),
#  ('Nine Inch Nails', 'Birthplace not found'),
#  ('David Guetta', 'Birthplace not found'),
#  ('Buffy Sainte-Marie', 'Stoneham'),
#  ('The Kinks', 'Birthplace not found'),
#  ('Nile Rodgers', 'New York City'),
#  ('John Green', 'Indianapolis'),
#  ('Naomi Judd', 'Ashland'),
#  ('Ann Wilson', 'San Diego'),
#  ('Kiersey Clemons', 'Los Angeles'),
#  ('Carly Rae Jepsen', 'Mission'),
#  ('Anna Camp', 'Aiken'),
#  ('Adrienne Barbeau', 'Sacramento'),
#  ('Jim Varney', 'Lexington'),
#  ('Phil Lynott', 'West Bromwich'),
#  ('Lauren Daigle', 'Lafayette'),
#  ('Timbaland', 'Norfolk'),
#  ('The Pussycat Dolls', 'Birthplace not found'),
#  ('Colman Domingo', 'Philadelphia'),
#  ('The Prodigy', 'Birthplace not found'),
#  ('Sean Paul', 'Kingston'),
#  ('Maren Morris', 'Arlington'),
#  ('Katt Williams', 'Birthplace not found'),
#  ('The Moody Blues', 'Birthplace not found'),
#  ('Richard Kind', 'Trenton'),
#  ('Irene Cara', 'New York City'),
#  ('Rashid Khan', 'Budaun'),
#  ('Natalia Tena', 'London'),
#  ('Michael Palin', 'Broomhill & Sharrow Vale'),
#  ('Stephen Stills', 'Dallas'),
#  ('Delta Goodrem', 'Sydney'),
#  ('Pat Benatar', 'Brooklyn'),
#  ('Belle Delphine', 'Birthplace not found'),
#  ('Barry White', 'Galveston'),
#  ('Village People', 'Birthplace not found'),
#  ('Harry Connick Jr.', 'New Orleans'),
#  ('Lucie Arnaz', 'Hollywood'),
#  ('The Clash', 'Birthplace not found'),
#  ('BjÃ¶rn Ulvaeus', 'Birthplace not found'),
#  ('Christine and the Queens', 'Nantes'),
#  ('Mos Def', 'Brooklyn'),
#  ('Jermaine Jackson', 'Gary'),
#  ('Laura Benanti', 'New York City'),
#  ('Graham Nash', 'Birthplace not found'),
#  ('Maroon 5', 'Birthplace not found'),
#  ('Lee Byung-hun', 'Seoul'),
#  ('Ghost', 'Kingston'),
#  ('Patti LuPone', 'Northport'),
#  ('Daryl Hall', 'Birthplace not found'),
#  ('Johnny Marr', 'Manchester'),
#  ('Dwight Yoakam', 'Pikeville'),
#  ('Brendon Urie', 'St. George'),
#  ('Susan Lucci', 'Scarsdale'),
#  ('Sanaa Lathan', 'Birthplace not found'),
#  ('Gary Barlow', 'Frodsham'),
#  ('Saweetie', 'Hayward'),
#  ('Debbie Allen', 'Houston'),
#  ('Ryan Bingham', 'Hobbs'),
#  ('Tamera Mowry', 'Gelnhausen'),
#  ('GÃ©rard Depardieu', 'Birthplace not found'),
#  ('Luis Miguel', 'San Juan'),
#  ('Mark Salling', 'Dallas'),
#  ('JhenÃ© Aiko', 'Birthplace not found'),
#  ('Yungblud', 'Doncaster'),
#  ('Kim Jong-hyun', 'Hyehwa-dong'),
#  ('Javed Akhtar', 'Birthplace not found'),
#  ('Randy Newman', 'Los Angeles'),
#  ('Charlotte Rampling', 'Sturmer'),
#  ('Stormzy', 'Croydon'),
#  ('Bindi Irwin', 'Buderim'),
#  ('Neil Peart', 'Birthplace not found'),
#  ('Carice van Houten', 'Leiderdorp'),
#  ('Tenacious D', 'Birthplace not found'),
#  ('Dilraba Dilmurat', 'Ürümqi'),
#  ('Tyra Banks', 'Inglewood'),
#  ('The Pretenders', 'Birthplace not found'),
#  ('Lea Salonga', 'Ermita'),
#  ('Kathie Lee Gifford', 'Paris'),
#  ('Jeezy', 'Birthplace not found'),
#  ('Mare Winningham', 'Phoenix'),
#  ('Jim Cummings', 'Youngstown'),
#  ('Grant Gustin', 'Norfolk'),
#  ('PJ Harvey', 'Corscombe'),
#  ('Benny Andersson', 'Stockholm'),
#  ('Amy Grant', 'Augusta'),
#  ('Billy Gibbons', 'Houston'),
#  ('The Allman Brothers Band', 'Birthplace not found'),
#  ('Merle Haggard', 'Bakersfield'),
#  ('Falling in Reverse', 'Birthplace not found'),
#  ('Bonnie Tyler', 'Skewen'),
#  ('Timbuktu', 'Lund Cathedral parish'),
#  ('Steve Kazee', 'Ashland'),
#  ('Matthias SchweighÃ¶fer', 'Birthplace not found'),
#  ('No Doubt', 'Birthplace not found'),
#  ('Tila Tequila', 'Singapore'),
#  ('Isabelle Adjani', '17th arrondissement of Paris'),
#  ('Kazuo Ishiguro', 'Birthplace not found'),
#  ('Randy Rhoads', 'Birthplace not found'),
#  ('Kenny Loggins', 'Everett'),
#  ('Swizz Beatz', 'The Bronx'),
#  ('Li Bingbing', 'Wuchang'),
#  ('ThalÃ\xada', 'Birthplace not found'),
#  ('The Hollies', 'Birthplace not found'),
#  ('Metta Sandiford-Artest', 'Birthplace not found'),
#  ('Michael Nesmith', 'Houston'),
#  ('Sturgill Simpson', 'Jackson'),
#  ('Cilla Black', 'Vauxhall'),
#  ('MC Hammer', 'Oakland'),
#  ('Emmylou Harris', 'Birthplace not found'),
#  ('Jeffree Star', 'Santa Ana'),
#  ('Daddy Yankee', 'San Juan'),
#  ('Sophie Marceau', '15th arrondissement of Paris'),
#  ('Sonny Chiba', 'Fukuoka'),
#  ('Darren Criss', 'San Francisco'),
#  ('Siouxsie Sioux', 'Southwark'),
#  ('Steve Vai', 'Birthplace not found'),
#  ('Nusrat Fateh Ali Khan', 'Faisalabad'),
#  ('Kapil Sharma', 'Amritsar'),
#  ('Peter Gallagher', 'Manhattan'),
#  ('Lindsey Stirling', 'Santa Ana'),
#  ('Sulli', 'Haeundae District'),
#  ('S Club 7', 'Birthplace not found'),
#  ('Jodi Benson', 'Rockford'),
#  ('Roxette', 'Birthplace not found'),
#  ('Eric Idle', 'Birthplace not found'),
#  ('Donovan', 'Glasgow'),
#  ('Geddy Lee', 'Toronto'),
#  ('Matt Bellamy', 'Cambridge'),
#  ('Brad Paisley', 'Glen Dale'),
#  ('Mumford & Sons', 'Birthplace not found'),
#  ('Benjamin Zephaniah', 'Handsworth'),
#  ('Logic', 'Rockville'),
#  ('Lesley Ann Warren', 'New York City'),
#  ('Bill Withers', 'Slab Fork'),
#  ('Bon Iver', 'Birthplace not found'),
#  ('Roberta Flack', 'Asheville'),
#  ('Rauw Alejandro', 'San Juan'),
#  ('Three 6 Mafia', 'Birthplace not found'),
#  ('Kacey Musgraves', 'Mineola'),
#  ('The Pointer Sisters', 'Birthplace not found'),
#  ('Tobias Forge', 'Q10658347'),
#  ('John Oates', 'Birthplace not found'),
#  ('Denny Doherty', 'Halifax'),
#  ('Sarah Brightman', 'Berkhamsted'),
#  ('Gregory Hines', 'New York City'),
#  ('Rick Springfield', 'Sydney'),
#  ('Iwan Rheon', 'Carmarthen'),
#  ('Cypress Hill', 'Birthplace not found'),
#  ('Stromae', 'Birthplace not found'),
#  ('John Prine', 'Maywood'),
#  ('Leona Lewis', 'London'),
#  ("Da'Vine Joy Randolph", 'Philadelphia'),
#  ('Autumn', 'Birthplace not found'),
#  ('Melissa Etheridge', 'Leavenworth'),
#  ('The Edge', 'London'),
#  ('Gotye', 'Bruges'),
#  ('Vani Jairam', 'Vellore'),
#  ('George Ezra', 'Hertford'),
#  ('Rosanne Cash', 'Memphis'),
#  ('Amy Madigan', 'Chicago'),
#  ('Maluma', 'Medellín'),
#  ('Mark Selby', 'Enid'),
#  ('Psy', 'Gangnam District'),
#  ('Jeff Healey', 'Toronto'),
#  ('Marianne Faithfull', 'Hampstead'),
#  ('Marie Fredriksson', 'Össjö'),
#  ('Rob Brydon', 'Baglan'),
#  ('New Edition', 'Birthplace not found'),
#  ('Jacob Collier', 'London'),
#  ('Bryan Ferry', 'Birthplace not found'),
#  ('Ilaiyaraaja', 'Pannaipuram'),
#  ('Nightwish', 'Birthplace not found'),
#  ('Christopher Cross', 'San Antonio'),
#  ('Haydn Gwynne', 'Hurstpierpoint'),
#  ('Sepultura', 'Birthplace not found'),
#  ('Yuvan Shankar Raja', 'Chennai'),
#  ('Rita Marley', 'Santiago de Cuba'),
#  ('Ziggy Marley', 'Kingston'),
#  ('Alison Krauss', 'Decatur'),
#  ('Shane Dawson', 'Long Beach'),
#  ('Peter Criss', 'Brooklyn'),
#  ('Joe Bonamassa', 'New Hartford'),
#  ('S. P. Balasubrahmanyam', 'Sri Potti Sri Ramulu Nellore district'),
#  ('Twenty One Pilots', 'Birthplace not found'),
#  ('Sutton Foster', 'Statesboro'),
#  ('Gram Parsons', 'Winter Haven'),
#  ('Tom Hulce', 'Detroit'),
#  ('Trivikram Srinivas', 'Birthplace not found'),
#  ('Tones and I', 'Mount Martha'),
#  ('Sheridan Smith', 'Epworth'),
#  ('Nina Hoss', 'Stuttgart'),
#  ('Dee Bradley Baker', 'Bloomington'),
#  ("Jane's Addiction", 'Birthplace not found'),
#  ('Tony Iommi', 'Birthplace not found'),
#  ('Zara Larsson', 'Solna Municipality'),
#  ('Arnel Pineda', 'Sampaloc'),
#  ('Sheila E.', 'Oakland'),
#  ('Trisha Yearwood', 'Monticello'),
#  ('Crystal Gayle', 'Paintsville'),
#  ("Olivia d'Abo", 'London'),
#  ('Giorgio Moroder', 'Birthplace not found'),
#  ('Anita Baker', 'Toledo'),
#  ('Chow Yun-fat', 'Hong Kong'),
#  ('Roger Allam', 'Bow'),
#  ('David Coverdale', 'Saltburn-by-the-Sea'),
#  ('Big Sean', 'Santa Monica'),
#  ('Sarah McLachlan', 'Halifax'),
#  ('Arshad Warsi', 'Mumbai'),
#  ('Sheena Easton', 'Bellshill'),
#  ('Sonu Nigam', 'Faridabad'),
#  ('Buffalo Springfield', 'Birthplace not found'),
#  ('Tuva Novotny', 'Stockholm'),
#  ('Thomas Bangalter', 'Paris'),
#  ('Run-DMC', 'Birthplace not found'),
#  ('Townes Van Zandt', 'Fort Worth'),
#  ('Moira Kelly', 'Queens'),
#  ('Ryan Tedder', 'Tulsa'),
#  ('Tomorrow X Together', 'Birthplace not found'),
#  ('Patrick Stump', 'Evanston'),
#  ('G-Dragon', 'Seoul'),
#  ('Beef', 'Birthplace not found'),
#  ('Paul Weller', 'Woking'),
#  ('Franka Potente', 'Münster'),
#  ('Len Cariou', 'Winnipeg'),
#  ('Ray Davies', 'Fortis Green'),
#  ('Eurythmics', 'Birthplace not found'),
#  ('Ashley McBryde', 'Mammoth Spring'),
#  ('Anne Murray', 'Nova Scotia'),
#  ('Harvey Fierstein', 'Brooklyn'),
#  ('Carla Bruni', 'Turin'),
#  ('Diane Warren', 'Van Nuys'),
#  ("The Go-Go's", 'Birthplace not found'),
#  ('Astrud Gilberto', 'Salvador'),
#  ('Timothy B. Schmit', 'Oakland'),
#  ('The Guess Who', 'Birthplace not found'),
#  ('Kraftwerk', 'Birthplace not found'),
#  ('Little Simz', 'Islington'),
#  ('John Entwistle', 'Birthplace not found'),
#  ('Aaron Tveit', 'Middletown'),
#  ('John Barrowman', 'Glasgow'),
#  ('Jasmine Guy', 'Boston'),
#  ('Annaleigh Ashford', 'Denver'),
#  ('D12', 'Birthplace not found'),
#  ('August Alsina', 'New Orleans'),
#  ('Nick Mason', 'Birthplace not found'),
#  ('Hayley Kiyoko', 'Los Angeles'),
#  ('Helen Reddy', 'Melbourne'),
#  ('Lenny Henry', 'Dudley'),
#  ('Modern Talking', 'Birthplace not found'),
#  ('Wizkid', 'Lagos'),
#  ('Mick Hucknall', 'Denton'),
#  ('Tim Minchin', 'Northampton'),
#  ('Sunidhi Chauhan', 'New Delhi'),
#  ('Julie Delpy', '14th arrondissement of Paris'),
#  ('Gulzar', 'Birthplace not found'),
#  ('Roxy Music', 'Birthplace not found'),
#  ('Owl City', 'Birthplace not found'),
#  ('Pedro AlmodÃ³var', 'Birthplace not found'),
#  ('Rain', 'Seoul'),
#  ('Lou Gramm', 'Rochester'),
#  ('Bernard Tapie', '20th arrondissement of Paris'),
#  ('Tracey Ullman', 'Slough'),
#  ('Bobbie Gentry', 'Woodland'),
#  ('Christopher Atkins', 'Rye'),
#  ('Jinkx Monsoon', 'Portland'),
#  ('Alan Menken', 'Birthplace not found'),
#  ('Hootie & the Blowfish', 'Birthplace not found'),
#  ('James Marsters', 'Greenville'),
#  ('Itzy', 'Birthplace not found'),
#  ('Craig Bierko', 'New York City'),
#  ('Wyclef Jean', 'Croix-des-Bouquets'),
#  ('Bob Weir', 'San Francisco'),
#  ('Mike Oldfield', 'Reading'),
#  ('Liza Soberano', 'Santa Clara'),
#  ('Tove Lo', 'Viken church parish'),
#  ('Marina Diamandis', 'Brynmawr'),
#  ('Bachmanâ€“Turner Overdrive', 'Birthplace not found'),
#  ('Cheyenne Jackson', 'Spokane'),
#  ('Wang Yibo', 'Luoyang'),
#  ('Jay Chou', 'Taipei'),
#  ('John Farnham', 'Dagenham'),
#  ('Francis Magalona', 'Manila'),
#  ('Roger Whittaker', 'Nairobi'),
#  ('J Balvin', 'Medellín'),
#  ('Smiley', 'Pitești'),
#  ('Shu Qi', 'Xindian District'),
#  ('Noa Kirel', "Ra'anana"),
#  ('Guy-Manuel de Homem-Christo', 'Neuilly-sur-Seine'),
#  ('Typhoon', 'Busan'),
#  ('Udit Narayan', 'Supaul district'),
#  ('Beverley Knight', 'Wolverhampton'),
#  ('Counting Crows', 'Birthplace not found'),
#  ('Andy Lau', 'Tai Po'),
#  ('Manic Street Preachers', 'Birthplace not found'),
#  ('Billy Ocean', 'Fyzabad'),
#  ('Betty Buckley', 'Big Spring'),
#  ('Kelly Bishop', 'Colorado Springs'),
#  ('Anika Noni Rose', 'Bloomfield'),
#  ('Dixie Carter', 'McLemoresville'),
#  ('Neal Schon', 'Birthplace not found'),
#  ('KC and the Sunshine Band', 'Birthplace not found'),
#  ('Mamta Mohandas', 'Manama'),
#  ('Jonny Greenwood', 'Birthplace not found'),
#  ('Bushido', 'Birthplace not found'),
#  ('Guy Sebastian', 'Klang'),
#  ('TiÃ«sto', 'Birthplace not found'),
#  ('JosÃ© Feliciano', 'Birthplace not found'),
#  ('John Paul Jones', 'Birthplace not found'),
#  ('Jill Hennessy', 'Edmonton'),
#  ('Steve Earle', 'Fort Monroe'),
#  ('Rufus Wainwright', 'Rhinebeck'),
#  ('Lou Doillon', 'Neuilly-sur-Seine'),
#  ('2 Chainz', 'Birthplace not found'),
#  ("Dixie D'Amelio", 'Norwalk'),
#  ('Madelaine Petsch', 'Port Orchard'),
#  ('Michael Parks', 'Corona'),
#  ('Ahmed Best', 'New York City'),
#  ('Vishal Bhardwaj', 'Bijnor'),
#  ('Grandmaster Flash', 'Birthplace not found'),
#  ('Atif Aslam', 'Wazirabad'),
#  ('Mithoon', 'Mumbai'),
#  ('Romeo Santos', 'The Bronx'),
#  ('Marla Gibbs', 'John H. Stroger, Jr. Hospital of Cook County'),
#  ('Beverley Mitchell', 'Arcadia'),
#  ('Carly Pearce', 'Taylor Mill'),
#  ('Marty Stuart', 'Philadelphia'),
#  ('Lady A', 'Birthplace not found'),
#  ('Jess Glynne', 'London'),
#  ('Konnan', 'Santiago de Cuba'),
#  ('RaÃºl Esparza', 'Birthplace not found'),
#  ('Alessia Cara', 'Mississauga'),
#  ('Bruce Hornsby', 'Williamsburg'),
#  ('Midge Ure', 'Cambuslang'),
#  ('Ray Manzarek', 'Chicago'),
#  ('In Flames', 'Birthplace not found'),
#  ('Diana Krall', 'Birthplace not found'),
#  ('Taylor York', 'Birthplace not found'),
#  ('Harry Chapin', 'Brooklyn'),
#  ('The Hives', 'Birthplace not found'),
#  ('Jharrel Jerome', 'Birthplace not found'),
#  ('The Roots', 'Birthplace not found'),
#  ('5 Seconds of Summer', 'Birthplace not found'),
#  ('Vicente FernÃ¡ndez', 'Birthplace not found'),
#  ('Eve', 'Philadelphia'),
#  ('Ethel Merman', 'Astoria'),
#  ('Mallika Sarabhai', 'Ahmedabad'),
#  ('Tamar Braxton', 'Severn'),
#  ('Brian McKnight', 'Buffalo'),
#  ('David Essex', 'Plaistow'),
#  ('Nazia Hassan', 'Karachi'),
#  ('Donny Hathaway', 'Chicago'),
#  ('Martine McCutcheon', 'London Borough of Hackney'),
#  ('BoA', 'Guri'),
#  ('Men at Work', 'Birthplace not found'),
#  ('Randy Bachman', 'Winnipeg'),
#  ('The-Dream', 'Atlanta'),
#  ('Bobby Womack', 'Birthplace not found'),
#  ('John Cale', 'Garnant'),
#  ('Anthony Field', 'Birthplace not found'),
#  ('Ian Anderson', 'Dunfermline'),
#  ('The Zombies', 'Birthplace not found'),
#  ('Public Enemy', 'Birthplace not found'),
#  ('Morten Harket', 'Kongsberg Municipality'),
#  ('Derek Trucks', 'Birthplace not found'),
#  ('Tegan and Sara', 'Birthplace not found'),
#  ('Anastacia', 'Chicago'),
#  ('Culture Club', 'Birthplace not found'),
#  ('Kumar Sanu', 'Kolkata'),
#  ('Victoria Wood', 'Prestwich'),
#  ("Terry O'Quinn", 'Sault Ste. Marie'),
#  ('Stefflon Don', 'Birmingham'),
#  ('Carole Bayer Sager', 'Brooklyn'),
#  ('Arcade Fire', 'Birthplace not found'),
#  ('Dan Fogler', 'Brooklyn'),
#  ('Toni Basil', 'Philadelphia'),
#  ('Michael Ball', 'Bromsgrove'),
#  ('Neneh Cherry', 'Stockholm'),
#  ('Nirvana', 'Birthplace not found'),
#  ('Jane Horrocks', 'Rawtenstall'),
#  ('Noddy Holder', 'Walsall'),
#  ('Pierce the Veil', 'Birthplace not found'),
#  ('Omega', 'Bonao'),
#  ('Magnet', 'Bergen'),
#  ('En Vogue', 'Birthplace not found'),
#  ('Ian Gillan', 'Chiswick'),
#  ('Mai Tai', 'Birthplace not found'),
#  ('RenÃ©e Elise Goldsberry', 'Birthplace not found'),
#  ('Keri Hilson', 'Decatur'),
#  ('Yunjin Kim', 'Seoul'),
#  ('Kym Marsh', 'Whiston'),
#  ('Howard Donald', 'Droylsden'),
#  ('Clint Black', 'Long Branch'),
#  ('Vic Mignogna', 'Greensburg'),
#  ('Alex Lifeson', 'Birthplace not found'),
#  ('Carroll Baker', 'Birthplace not found'),
#  ('Peter Kay', 'Farnworth'),
#  ('Dweezil Zappa', 'Birthplace not found'),
#  ('Barry Bostwick', 'San Mateo'),
#  ('Gil Scott-Heron', 'Chicago'),
#  ('Edgar Winter', 'Beaumont'),
#  ('Chris Colfer', 'Clovis'),
#  ('Amanda Lear', 'Ho Chi Minh City'),
#  ('Adam Clayton', 'Birthplace not found'),
#  ('Hector', '7th arrondissement of Paris'),
#  ('Johnny Winter', 'Beaumont'),
#  ('Shweta Mohan', 'Thiruvananthapuram'),
#  ('Katie Melua', 'Kutaisi'),
#  ('Martin Garrix', 'Birthplace not found'),
#  ('Heather Headley', 'Barataria'),
#  ('Crowded House', 'Birthplace not found'),
#  ('Hwasa', 'Jeonju'),
#  ('CeCe Winans', 'Detroit'),
#  ('Devi Sri Prasad', 'Vedurupaka')]

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
birthplaces_df = pd.DataFrame(artist_birthplaces, columns=['Artist', 'Birthplace'])

# Save to CSV
output_csv_path = 'artist_birthplaces.csv'
birthplaces_df.to_csv(output_csv_path, index=False)

print(f"Data saved to {output_csv_path}. You can now download this file.")
# Out:
# Data saved to artist_birthplaces.csv. You can now download this file.

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
from google.colab import files

files.download("artist_birthplaces.csv")

# %% [markdown]
# ### Installation and Import of SPARQLWrapper Library
# This section installs `SPARQLWrapper` to enable querying RDF databases using SPARQL directly from Python.

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import time

# Load the CSV file
df = pd.read_csv('artist_birthplaces.csv')

# Initialize the geocoder with a user-agent (replace 'my_geocoder' with your application name)
geolocator = Nominatim(user_agent="my_geocoder")

# This will help manage the rate of your requests
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# Define a function to get coordinates
def get_coordinates(city):
    try:
        location = geocode(city)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except:
        return None, None

# Apply the function to your DataFrame
df['coordinates'] = df['Birthplace'].apply(get_coordinates)

# Optional: split the coordinates into two columns for latitude and longitude
df[['latitude', 'longitude']] = pd.DataFrame(df['coordinates'].tolist(), index=df.index)

# Save the updated DataFrame to a new CSV file
df.to_csv('artist_birthplaces_with_coordinates.csv', index=False)

print(df.head())
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Huntington&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Los+Angeles&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Toronto&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Hollywood&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Los+Angeles&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=San+Juan&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Los+Angeles&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Birthplace+not+found&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Charlotte&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=San+Juan&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Toronto&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Birthplace+not+found&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Supaul+district&format=json&limit=1
#          Artist    Birthplace                coordinates   latitude  longitude
# 0  Taylor Swift  West Reading  (40.3337038, -75.9474322)  40.333704 -75.947432
# 1  XXXTentacion    Plantation  (27.0637262, -82.3651631)  27.063726 -82.365163
# 2    Alia Bhatt         India   (22.3511148, 78.6677428)  22.351115  78.667743
# 3   Tina Turner   Brownsville  (25.9024289, -97.4981698)  25.902429 -97.498170
# 4  Keanu Reeves        Beirut     (33.8959203, 35.47843)  33.895920  35.478430

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
files.download("artist_birthplaces_with_coordinates.csv")

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
import pandas as pd

top_visited = pd.read_excel("/content/names_2023_visits.xlsx")
top_visited
# Out:
#            name,2023_visits
# 0     Taylor Swift,22030018
# 1     XXXTentacion,20104479
# 2       Alia Bhatt,12669342
# 3      Tina Turner,11590403
# 4      Keanu Reeves,9916477
# ...                     ...
# 4914         Martine Bijl,1
# 4915            k.d. lang,1
# 4916            apl.de.ap,1
# 4917  Noncho Vodenicharov,1
# 4918      Sergey Zakharov,1
#
# [4919 rows x 1 columns]

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
split_data = top_visited['name,2023_visits'].str.split(',', expand=True)
if split_data.shape[1] == 2:  # Assicurati che ci siano esattamente 2 colonne dopo la divisione
    top_visited[['name', '2023views']] = split_data

top_visited.head()
# Out:
#         name,2023_visits
# 0  Taylor Swift,22030018
# 1  XXXTentacion,20104479
# 2    Alia Bhatt,12669342
# 3   Tina Turner,11590403
# 4   Keanu Reeves,9916477

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
df = split_data.dropna(axis=1)
df = df.rename(columns={0 : "Artist",
                   1: "views"})
print(df.head())
# Out:
#          Artist     views
# 0  Taylor Swift  22030018
# 1  XXXTentacion  20104479
# 2    Alia Bhatt  12669342
# 3   Tina Turner  11590403
# 4  Keanu Reeves   9916477

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
df = df.iloc[:996]

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
data2 = pd.read_csv("/content/artist_birthplaces_with_coordinates.csv")
data2
# Out:
#               Artist            Birthplace  \
# 0       Taylor Swift          West Reading
# 1       XXXTentacion            Plantation
# 2         Alia Bhatt                 India
# 3        Tina Turner           Brownsville
# 4       Keanu Reeves                Beirut
# ..               ...                   ...
# 991  Heather Headley             Barataria
# 992    Crowded House  Birthplace not found
# 993            Hwasa                Jeonju
# 994      CeCe Winans               Detroit
# 995  Devi Sri Prasad            Vedurupaka
#
#                                   coordinates   latitude   longitude
# 0                   (40.3337038, -75.9474322)  40.333704  -75.947432
# 1                   (27.0637262, -82.3651631)  27.063726  -82.365163
# 2                    (22.3511148, 78.6677428)  22.351115   78.667743
# 3                   (25.9024289, -97.4981698)  25.902429  -97.498170
# 4                      (33.8959203, 35.47843)  33.895920   35.478430
# ..                                        ...        ...         ...
# 991  (29.704083500000003, -90.11145959181923)  29.704084  -90.111460
# 992                              (None, None)        NaN         NaN
# 993                 (35.8237631, 127.1472805)  35.823763  127.147280
# 994                 (42.3315509, -83.0466403)  42.331551  -83.046640
# 995                   (17.2076792, 81.851724)  17.207679   81.851724
#
# [996 rows x 5 columns]

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
views2023_df = df["views"].to_frame('views')

# Then you can merge using the correct column names
data = data2.merge(df[["Artist", 'views']], on='Artist', how='left')

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
from google.colab import files
data.to_csv("mapviews.csv", index = False)
files.download("mapviews.csv")

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/top_visits_per_day")
data
# Out:
#      Unnamed: 0        date  \
# 0             0  2023-01-01
# 1             1  2023-01-02
# 2             2  2023-01-03
# 3             3  2023-01-04
# 4             4  2023-01-05
# ..          ...         ...
# 360         360  2023-12-27
# 361         361  2023-12-28
# 362         362  2023-12-29
# 363         363  2023-12-30
# 364         364  2023-12-31
#
#                                            top_artists            top_1  \
# 0    ['David Byrne', 'Miley Cyrus', 'The Pointer Si...      David Byrne
# 1    ['Tanya Tucker', 'The Pointer Sisters', 'Tammy...     Tanya Tucker
# 2    ['Whitney Houston', 'Tammy Wynette', 'XXXTenta...  Whitney Houston
# 3    ['XXXTentacion', 'Whitney Houston', 'Tammy Wyn...     XXXTentacion
# 4    ['Shania Twain', 'XXXTentacion', 'Whitney Hous...     Shania Twain
# ..                                                 ...              ...
# 360      ['XXXTentacion', 'Salman Khan', 'Alia Bhatt']     XXXTentacion
# 361          ['XXXTentacion', 'Cher', 'Queen Latifah']     XXXTentacion
# 362           ['XXXTentacion', 'Taylor Swift', 'Cher']     XXXTentacion
# 363    ['XXXTentacion', 'Tina Turner', 'Taylor Swift']     XXXTentacion
# 364    ['XXXTentacion', 'Tina Turner', 'Taylor Swift']     XXXTentacion
#
#                    top_2                top_3
# 0            Miley Cyrus  The Pointer Sisters
# 1    The Pointer Sisters        Tammy Wynette
# 2          Tammy Wynette         XXXTentacion
# 3        Whitney Houston        Tammy Wynette
# 4           XXXTentacion      Whitney Houston
# ..                   ...                  ...
# 360          Salman Khan           Alia Bhatt
# 361                 Cher        Queen Latifah
# 362         Taylor Swift                 Cher
# 363          Tina Turner         Taylor Swift
# 364          Tina Turner         Taylor Swift
#
# [365 rows x 6 columns]

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
unique_top_1 = data["top_1"].unique()

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
unique_artists = pd.unique(data[['top_1', 'top_2', 'top_3']].values.ravel('K'))
unique_artists
# Out:
# array(['David Byrne', 'Tanya Tucker', 'Whitney Houston', 'XXXTentacion',
#        'Shania Twain', 'Rod Stewart', 'David Bowie', 'Tammy Wynette',
#        'Anna Kendrick', 'Jeff Beck', 'Michael Jackson', 'Shakira',
#        'Miley Cyrus', 'David Crosby', 'Paris Hilton', 'Anita Baker',
#        'Penny Marshall', 'Austin Butler', 'Vani Jairam', 'Kim Petras',
#        'Salma Hayek', 'Rihanna', 'Raquel Welch', 'Bruce Willis',
#        'Hayden Panettiere', 'Lewis Capaldi', 'Linda Ronstadt',
#        'Olivia Newton-John', 'Sally Field', 'Steven Seagal', 'Ed Sheeran',
#        'Selena Gomez', 'Lynyrd Skynyrd', 'Niall Horan', 'Michael Bolton',
#        'Stevie Nicks', 'Sarah Polley', 'Taylor Swift', 'Toni Collette',
#        'Keanu Reeves', 'Gwyneth Paltrow', 'Adam Sandler', 'Lainey Wilson',
#        'Luis Enrique', 'S Club 7', 'Joe Alwyn', 'The Beach Boys',
#        'Jon Bon Jovi', 'Steven Yeun', 'Jamie Foxx', 'Frank Ocean',
#        'Avicii', 'Mark Selby', 'Jared Leto', 'Carrie Fisher',
#        'Katy Perry', 'Alanis Morissette', 'Hannah Waddingham',
#        'Nick Cannon', 'Donna Summer', 'Tina Turner', 'Astrud Gilberto',
#        'Barry Manilow', 'BTS', 'Ezra Miller', 'Golshifteh Farahani',
#        'Bebe Rexha', 'Zendaya', 'Arctic Monkeys', "Guns N' Roses",
#        'Elton John', 'Madonna', 'Jackie Chan', 'George Michael',
#        'Amy Winehouse', 'Jane Birkin', 'Tupac Shakur', 'Ethan Slater',
#        'Ryan Gosling', 'Mick Jagger', 'Lizzo', 'Wayne Brady',
#        'Tory Lanez', 'Alia Bhatt', 'Zooey Deschanel', 'Britney Spears',
#        'Jack Antonoff', 'Mary Elizabeth Winstead', 'Jimmy Buffett',
#        'Olivia Rodrigo', 'Mark Wahlberg', 'Grimes', 'Hugh Jackman',
#        'Russell Brand', 'Victoria Beckham', 'Suzanne Somers',
#        'Robert Downey Jr.', 'Haydn Gwynne', 'The Beatles',
#        'Barbra Streisand', 'Robbie Williams', 'Sean Combs', 'Cher',
#        'Brenda Song', 'Benjamin Zephaniah', 'Eminem',
#        'Kris Kristofferson', 'The Chicks', 'The Pointer Sisters',
#        'Freddie Mercury', 'Hans Zimmer', 'Eddie Murphy', 'The Yardbirds',
#        'The Byrds', 'Roberta Flack', 'Julia Louis-Dreyfus',
#        'Bradley Cooper', 'Marc Anthony', 'Michael McKean',
#        'Ozzy Osbourne', 'Brandi Carlile', 'Sam Smith', 'Chris Stapleton',
#        'Chris Brown', 'Post Malone', 'R. Kelly', 'Avril Lavigne',
#        'Angela Bassett', 'Scarlett Johansson', 'Andrew Lloyd Webber',
#        'Joni Mitchell', 'Meghan Trainor', 'Coolio', 'Lionel Richie',
#        'Priyanka Chopra', 'Doja Cat', 'Kate Winslet', 'Sidhu Moose Wala',
#        'Vanessa Paradis', 'Johnny Depp', 'Ariana DeBose', 'Cat Stevens',
#        'Keke Palmer', 'Charlotte Gainsbourg', 'Florence Pugh',
#        'Travis Scott', 'Jisoo', 'Megan Thee Stallion', 'The Band',
#        'Steve Harvey', 'The Rolling Stones', 'Damian Lillard',
#        'Toby Keith', 'Jada Pinkett Smith', 'KSI', 'Justin Timberlake',
#        'Bad Bunny', 'Buffy Sainte-Marie', 'Paula Abdul', 'Tracy Chapman',
#        'Nicole Kidman', 'Robert Pattinson', 'Jack Harlow', 'Jason Mraz',
#        'The Pogues', 'Billie Eilish', 'Nelly', 'Kylie Minogue',
#        'Bob Marley', 'Salman Khan', 'Jessie J', 'Kate Hudson',
#        'Maya Rudolph', 'Megan Mullally', 'Bonnie Raitt',
#        'Sheryl Lee Ralph', 'Jack White', 'Lele Pons', 'Lady Gaga',
#        'Zachary Levi', 'Daniel Radcliffe', 'John Cena', 'Brian Wilson',
#        'Lauren Daigle', 'Bee Gees', "Beverly D'Angelo", 'Tila Tequila',
#        'Kanye West', 'Dave Grohl', 'Ray Davies', 'Lou Doillon',
#        'Peter Gabriel', 'Rajinikanth', 'Missy Elliott',
#        'The Notorious B.I.G.', 'Sufjan Stevens', 'Will Smith',
#        'John Denver', 'Fleetwood Mac', 'Tim Curry', 'Andrea Bocelli',
#        'Snoop Dogg', 'Dua Lipa', 'David Foster', "Catherine O'Hara",
#        'Ne-Yo', 'Mariah Carey', 'Queen Latifah'], dtype=object)

# %% [markdown]
# ### Installation and Import of SPARQLWrapper Library
# This section installs `SPARQLWrapper` to enable querying RDF databases using SPARQL directly from Python.

# %%
pip install SPARQLWrapper
# Out:
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1 (from SPARQLWrapper)
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 7.2 MB/s eta 0:00:00
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=6.1.1->SPARQLWrapper)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Installing collected packages: isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 isodate-0.6.1 rdflib-7.0.0

# %% [markdown]
# ### Installation and Import of SPARQLWrapper Library
# This section installs `SPARQLWrapper` to enable querying RDF databases using SPARQL directly from Python.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def get_artist_images(artist_list):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    values_string = " ".join(f'"{artist}"' for artist in artist_list)  # Create a string for the SPARQL VALUES clause
    print("Debug - SPARQL VALUES Clause:", values_string)  # Debug print to check the VALUES clause

    query = f"""
    SELECT ?artist ?artistLabel ?image WHERE {{
      VALUES ?artistLabel {{{values_string}}}
      # ?artist rdfs:label ?artistLabel;
              wdt:P18 ?image.
      FILTER(LANG(?artistLabel) = "en")
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    LIMIT 100
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    images = []
    for result in results["results"]["bindings"]:
        artist_name = result["artistLabel"]["value"]
        image_url = result["image"]["value"]
        images.append((artist_name, image_url))
    return images

# Example usage with a list of artist names
artist_images = get_artist_images(unique_artists)  # Replace with your actual list of unique artists
for artist, url in artist_images:
    print(artist, url)
# Out:
# Debug - SPARQL VALUES Clause: "David Byrne" "Tanya Tucker" "Whitney Houston" "XXXTentacion" "Shania Twain" "Rod Stewart" "David Bowie" "Tammy Wynette" "Anna Kendrick" "Jeff Beck" "Michael Jackson" "Shakira" "Miley Cyrus" "David Crosby" "Paris Hilton" "Anita Baker" "Penny Marshall" "Austin Butler" "Vani Jairam" "Kim Petras" "Salma Hayek" "Rihanna" "Raquel Welch" "Bruce Willis" "Hayden Panettiere" "Lewis Capaldi" "Linda Ronstadt" "Olivia Newton-John" "Sally Field" "Steven Seagal" "Ed Sheeran" "Selena Gomez" "Lynyrd Skynyrd" "Niall Horan" "Michael Bolton" "Stevie Nicks" "Sarah Polley" "Taylor Swift" "Toni Collette" "Keanu Reeves" "Gwyneth Paltrow" "Adam Sandler" "Lainey Wilson" "Luis Enrique" "S Club 7" "Joe Alwyn" "The Beach Boys" "Jon Bon Jovi" "Steven Yeun" "Jamie Foxx" "Frank Ocean" "Avicii" "Mark Selby" "Jared Leto" "Carrie Fisher" "Katy Perry" "Alanis Morissette" "Hannah Waddingham" "Nick Cannon" "Donna Summer" "Tina Turner" "Astrud Gilberto" "Barry Manilow" "BTS" "Ezra Miller" "Golshifteh Farahani" "Bebe Rexha" "Zendaya" "Arctic Monkeys" "Guns N' Roses" "Elton John" "Madonna" "Jackie Chan" "George Michael" "Amy Winehouse" "Jane Birkin" "Tupac Shakur" "Ethan Slater" "Ryan Gosling" "Mick Jagger" "Lizzo" "Wayne Brady" "Tory Lanez" "Alia Bhatt" "Zooey Deschanel" "Britney Spears" "Jack Antonoff" "Mary Elizabeth Winstead" "Jimmy Buffett" "Olivia Rodrigo" "Mark Wahlberg" "Grimes" "Hugh Jackman" "Russell Brand" "Victoria Beckham" "Suzanne Somers" "Robert Downey Jr." "Haydn Gwynne" "The Beatles" "Barbra Streisand" "Robbie Williams" "Sean Combs" "Cher" "Brenda Song" "Benjamin Zephaniah" "Eminem" "Kris Kristofferson" "The Chicks" "The Pointer Sisters" "Freddie Mercury" "Hans Zimmer" "Eddie Murphy" "The Yardbirds" "The Byrds" "Roberta Flack" "Julia Louis-Dreyfus" "Bradley Cooper" "Marc Anthony" "Michael McKean" "Ozzy Osbourne" "Brandi Carlile" "Sam Smith" "Chris Stapleton" "Chris Brown" "Post Malone" "R. Kelly" "Avril Lavigne" "Angela Bassett" "Scarlett Johansson" "Andrew Lloyd Webber" "Joni Mitchell" "Meghan Trainor" "Coolio" "Lionel Richie" "Priyanka Chopra" "Doja Cat" "Kate Winslet" "Sidhu Moose Wala" "Vanessa Paradis" "Johnny Depp" "Ariana DeBose" "Cat Stevens" "Keke Palmer" "Charlotte Gainsbourg" "Florence Pugh" "Travis Scott" "Jisoo" "Megan Thee Stallion" "The Band" "Steve Harvey" "The Rolling Stones" "Damian Lillard" "Toby Keith" "Jada Pinkett Smith" "KSI" "Justin Timberlake" "Bad Bunny" "Buffy Sainte-Marie" "Paula Abdul" "Tracy Chapman" "Nicole Kidman" "Robert Pattinson" "Jack Harlow" "Jason Mraz" "The Pogues" "Billie Eilish" "Nelly" "Kylie Minogue" "Bob Marley" "Salman Khan" "Jessie J" "Kate Hudson" "Maya Rudolph" "Megan Mullally" "Bonnie Raitt" "Sheryl Lee Ralph" "Jack White" "Lele Pons" "Lady Gaga" "Zachary Levi" "Daniel Radcliffe" "John Cena" "Brian Wilson" "Lauren Daigle" "Bee Gees" "Beverly D'Angelo" "Tila Tequila" "Kanye West" "Dave Grohl" "Ray Davies" "Lou Doillon" "Peter Gabriel" "Rajinikanth" "Missy Elliott" "The Notorious B.I.G." "Sufjan Stevens" "Will Smith" "John Denver" "Fleetwood Mac" "Tim Curry" "Andrea Bocelli" "Snoop Dogg" "Dua Lipa" "David Foster" "Catherine O'Hara" "Ne-Yo" "Mariah Carey" "Queen Latifah"

# %% [markdown]
# ### Installation and Import of SPARQLWrapper Library
# This section installs `SPARQLWrapper` to enable querying RDF databases using SPARQL directly from Python.

# %%
import requests

def fetch_main_image_for_artists(artist_list):
    base_url = "https://en.wikipedia.org/w/api.php"
    images = []

    for artist in artist_list:
        params = {
            "action": "query",
            "format": "json",
            "titles": artist,
            "prop": "pageimages",  # Property to fetch images
            "pithumbsize": 500     # Thumbnail size
        }

        response = requests.get(base_url, params=params)
        data = response.json()

        # Navigate through the JSON to find the main page image URL
        pages = data.get('query', {}).get('pages', {})
        for page_id, page in pages.items():
            thumbnail = page.get('thumbnail', {}).get('source')
            if thumbnail:
                images.append((artist, thumbnail))
            else:
                images.append((artist, "No image available"))

    return images


# Fetch the main images
artist_images = fetch_main_image_for_artists(unique_artists)
for artist, image_url in artist_images:
    print(artist, image_url)
# Out:
# David Byrne https://upload.wikimedia.org/wikipedia/commons/thumb/5/54/David_Byrne_San_Diego.jpg/500px-David_Byrne_San_Diego.jpg
# Tanya Tucker https://upload.wikimedia.org/wikipedia/commons/thumb/3/3f/TanyaTuckerGraceland02202020.jpeg/500px-TanyaTuckerGraceland02202020.jpeg
# Whitney Houston https://upload.wikimedia.org/wikipedia/commons/thumb/5/52/Whitney_Houston_%28cropped3%29.JPEG/500px-Whitney_Houston_%28cropped3%29.JPEG
# XXXTentacion https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Xxxtentacion_%28cropped%29.jpg/500px-Xxxtentacion_%28cropped%29.jpg
# Shania Twain https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/
://upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Fleetwood_Mac_Billboard_1977.jpg/500px-Fleetwood_Mac_Billboard_1977.jpg
# Tim Curry https://upload.wikimedia.org/wikipedia/commons/thumb/5/58/Tim_Curry_cropped.jpg/500px-Tim_Curry_cropped.jpg
# Andrea Bocelli https://upload.wikimedia.org/wikipedia/commons/thumb/3/35/Andrea_Bocelli_20190511_017-2_%28cropped%29.jpg/500px-Andrea_Bocelli_20190511_017-2_%28cropped%29.jpg
# Snoop Dogg https://upload.wikimedia.org/wikipedia/commons/thumb/d/dc/Snoop_Dogg_in_2022_-_2.jpg/500px-Snoop_Dogg_in_2022_-_2.jpg
# Dua Lipa https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/DuaLipaO2020522_%28101_of_110%29_%2852052470251%29_%28cropped%29.jpg/500px-DuaLipaO2020522_%28101_of_110%29_%2852052470251%29_%28cropped%29.jpg
# David Foster https://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/David_Foster_by_Gage_Skidmore_2.jpg/500px-David_Foster_by_Gage_Skidmore_2.jpg
# Catherine O'Hara https://upload.wikimedia.org/wikipedia/commons/1/16/CATHERINE_OHARA.jpg
# Ne-Yo https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Ne_Yo_in_2018.png/500px-Ne_Yo_in_2018.png
# Mariah Carey https://upload.wikimedia.org/wikipedia/commons/2/22/Mariah_Carey_Library_of_Congress_2023_1_Cropped_3.png
# Queen Latifah https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Queen_Latifah_2018.jpg/500px-Queen_Latifah_2018.jpg

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
df = pd.DataFrame(artist_images, columns=['Artist', 'Image_URL'])

df.to_csv('artist_images.csv', index=False)

df.head()
# Out:
#             Artist                                          Image_URL
# 0      David Byrne  https://upload.wikimedia.org/wikipedia/commons...
# 1     Tanya Tucker  https://upload.wikimedia.org/wikipedia/commons...
# 2  Whitney Houston  https://upload.wikimedia.org/wikipedia/commons...
# 3     XXXTentacion  https://upload.wikimedia.org/wikipedia/commons...
# 4     Shania Twain  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/NUMBER_of_views")
df
# Out:
#         Unnamed: 0          article        date  views
# 0                0     Taylor Swift  2023-01-01  29705
# 1                1     Taylor Swift  2023-01-02  25766
# 2                2     Taylor Swift  2023-01-03  24682
# 3                3     Taylor Swift  2023-01-04  21214
# 4                4     Taylor Swift  2023-01-05  22873
# ...            ...              ...         ...    ...
# 356922      356922  Devi Sri Prasad  2023-12-27    588
# 356923      356923  Devi Sri Prasad  2023-12-28    636
# 356924      356924  Devi Sri Prasad  2023-12-29    706
# 356925      356925  Devi Sri Prasad  2023-12-30    686
# 356926      356926  Devi Sri Prasad  2023-12-31    720
#
# [356927 rows x 4 columns]

# %% [markdown]
# ### Fetching Artist Genres Using Requests
# This segment queries Wikidata for the music genres of artists, incorporating error handling for robust data fetching.

# %%
import requests


artists_data = df["article"]
unique_artists = artists_data.unique()

def fetch_artist_genre(artist_names):
    """Fetches the first genre for all artist names in the DataFrame using direct HTTP requests to the Wikidata endpoint."""
    wikidata_endpoint = "https://query.wikidata.org/sparql"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
        'Accept': 'application/sparql-results+json'
    }
    artist_genre_list = []  # This will hold the tuples of (artist_name, genre)

    for artist_name in artist_names:
        query = f"""
        SELECT ?artist ?genreLabel WHERE {{
          # ?artist wdt:P136 ?genre;  # Genre
                  rdfs:label "{artist_name}"@en.
          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
        }}
        LIMIT 1
        """
        try:
            response = requests.get(wikidata_endpoint, headers=headers, params={'query': query, 'format': 'json'})
            response.raise_for_status()  # Raises a HTTPError for bad responses
            data = response.json()
            if data["results"]["bindings"]:
                genre = data["results"]["bindings"][0]["genreLabel"]["value"]
                artist_genre_list.append((artist_name, genre))
            else:
                artist_genre_list.append((artist_name, "Genre not found"))
        except requests.RequestException as e:
            print(f"Request failed for artist {artist_name}: {e}")
            artist_genre_list.append((artist_name, "Request failed"))

    return artist_genre_list

# Fetching genres for all artists
artist_genres_data = fetch_artist_genre(unique_artists)

# Creating a DataFrame from the list of tuples
artist_genres_df = pd.DataFrame(artist_genres_data, columns=['Artist', 'Genre'])
print(artist_genres_df)
# Out:
#               Artist             Genre
# 0       Taylor Swift         pop music
# 1       XXXTentacion         punk rock
# 2         Alia Bhatt   Genre not found
# 3        Tina Turner     rock and roll
# 4       Keanu Reeves     hip hop music
# ..               ...               ...
# 991  Heather Headley        soul music
# 992    Crowded House  alternative rock
# 993            Hwasa              jazz
# 994      CeCe Winans      gospel music
# 995  Devi Sri Prasad       filmi music
#
# [996 rows x 2 columns]

# %% [markdown]
# ### Handling Missing Data
# Counts and handles missing genre information by replacing not found entries with a default label, enhancing data integrity.

# %%
genre_not_found_count = (artist_genres_df['Genre'] == 'Genre not found').sum()

print(f"Number of 'Genre not found' entries: {genre_not_found_count}")
# Out:
# Number of 'Genre not found' entries: 263

# %% [markdown]
# ### Handling Missing Data
# Counts and handles missing genre information by replacing not found entries with a default label, enhancing data integrity.

# %%
artist_genres_df['Genre'] = artist_genres_df['Genre'].replace('Genre not found', 'Unspecified')

# Displaying the updated DataFrame to verify the change
print(artist_genres_df)
# Out:
#               Artist             Genre
# 0       Taylor Swift         pop music
# 1       XXXTentacion         punk rock
# 2         Alia Bhatt       Unspecified
# 3        Tina Turner     rock and roll
# 4       Keanu Reeves     hip hop music
# ..               ...               ...
# 991  Heather Headley        soul music
# 992    Crowded House  alternative rock
# 993            Hwasa              jazz
# 994      CeCe Winans      gospel music
# 995  Devi Sri Prasad       filmi music
#
# [996 rows x 2 columns]

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
artist_genres_df.to_csv("artists_genres", index=False)

# %% [markdown]
# ### Data Export and Verification
# Exports the processed DataFrame to a CSV file and reloads it to verify the contents, ensuring data is saved correctly.

# %%
df = pd.read_csv("/content/artists_genres")
df
# Out:
#               Artist             Genre
# 0       Taylor Swift         pop music
# 1       XXXTentacion         punk rock
# 2         Alia Bhatt       Unspecified
# 3        Tina Turner     rock and roll
# 4       Keanu Reeves     hip hop music
# ..               ...               ...
# 991  Heather Headley        soul music
# 992    Crowded House  alternative rock
# 993            Hwasa              jazz
# 994      CeCe Winans      gospel music
# 995  Devi Sri Prasad       filmi music
#
# [996 rows x 2 columns]

# %% [markdown]
# ### Data Import
# This section imports necessary libraries and loads data from an Excel file.

# %%
import pandas as pd

# %% [markdown]
# ### Data Import
# This section imports necessary libraries and loads data from an Excel file.

# %%
top_visited = pd.read_excel("/content/top_visited_2023.xlsx")
split_data = top_visited['name,2023_visits'].str.split(',', expand=True)
if split_data.shape[1] == 2:  # Assicurati che ci siano esattamente 2 colonne dopo la divisione
    top_visited[['name', '2023views']] = split_data

top_visited.head()
# Out:
#         name,2023_visits
# 0  Taylor Swift,22030018
# 1  XXXTentacion,20104479
# 2    Alia Bhatt,12669342
# 3   Tina Turner,11590403
# 4   Keanu Reeves,9916477

# %% [markdown]
# ### Data Import
# This section imports necessary libraries and loads data from an Excel file.

# %%
df = split_data.dropna(axis=1)
print(df.head())
# Out:
#               0         1
# 0  Taylor Swift  22030018
# 1  XXXTentacion  20104479
# 2    Alia Bhatt  12669342
# 3   Tina Turner  11590403
# 4  Keanu Reeves   9916477

# %% [markdown]
# ### Data Import
# This section imports necessary libraries and loads data from an Excel file.

# %%
df = df.rename(columns={0 : "name",
                   1: "views2023"})

# %% [markdown]
# ### Data Import
# This section imports necessary libraries and loads data from an Excel file.

# %%
import requests
import pandas as pd

# I tuoi parametri di base
domain = 'en.wikipedia'
access = 'all-access'
agent = 'user'
start_date = '202301'  # YYYYMMDDc
end_date = '202312'  # YYYYMMDD
headers = {
    'User-Agent': 'MyDataVisualizationProject/1.0 (slykku2318@gmail.com)'
}

# La lista degli articoli da interrogare
names = df["name"]

# Inizializza un DataFrame vuoto per raccogliere i dati
all_views_data = pd.DataFrame()

# Ciclo attraverso ogni nome per costruire l'URL e fare la richiesta
for article in names:
    url = f'https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/{domain}/{access}/{agent}/{article}/daily/{start_date}01/{end_date}31'

    response = requests.get(url, headers=headers)
    data = response.json()

    # Elabora i dati per ogni articolo, se disponibili
    if 'items' in data:
        views_data = [{'article': article, 'date': item['timestamp'], 'views': item['views']} for item in data['items']]
        df = pd.DataFrame(views_data)

        # Converti timestamp in data leggibile
        df['date'] = pd.to_datetime(df['date'], format='%Y%m%d%H')

        # Aggiungi i dati al DataFrame principale
        all_views_data = pd.concat([all_views_data, df], ignore_index=True)
    else:
        print(f"Data not found or error in request for article: {article}")

# Mostra i primi dati raccolti
print(all_views_data.head())
# Out:
# Data not found or error in request for article: AC/DC
# Data not found or error in request for article: Michaela JaÃ© Rodriguez
# Data not found or error in request for article: KÃ¤Ã¤rijÃ¤
#         article       date  views
# 0  Taylor Swift 2023-01-01  29705
# 1  Taylor Swift 2023-01-02  25766
# 2  Taylor Swift 2023-01-03  24682
# 3  Taylor Swift 2023-01-04  21214
# 4  Taylor Swift 2023-01-05  22873

# %% [markdown]
# ### Data Analysis
# This function identifies the top 3 articles by views for each day and formats the results.

# %%
def top_3_artists(group):
    return group.sort_values('views', ascending=False).head(3)['article'].tolist()

# Raggruppa per 'date' e applica la funzione per ottenere i primi 3 artisti
top_artists_by_day = all_views_data.groupby('date').apply(top_3_artists).reset_index(name='top_artists')

# Espandi la lista dei top artisti in colonne separate
top_artists_by_day[['top_1', 'top_2', 'top_3']] = pd.DataFrame(top_artists_by_day['top_artists'].tolist(), index=top_artists_by_day.index)

# Mostra il risultato
print(top_artists_by_day[['date', 'top_1', 'top_2', 'top_3']])
# Out:
#           date            top_1                top_2                top_3
# 0   2023-01-01      David Byrne          Miley Cyrus  The Pointer Sisters
# 1   2023-01-02     Tanya Tucker  The Pointer Sisters        Tammy Wynette
# 2   2023-01-03  Whitney Houston        Tammy Wynette         XXXTentacion
# 3   2023-01-04     XXXTentacion      Whitney Houston        Tammy Wynette
# 4   2023-01-05     Shania Twain         XXXTentacion      Whitney Houston
# ..         ...              ...                  ...                  ...
# 360 2023-12-27     XXXTentacion          Salman Khan           Alia Bhatt
# 361 2023-12-28     XXXTentacion                 Cher        Queen Latifah
# 362 2023-12-29     XXXTentacion         Taylor Swift                 Cher
# 363 2023-12-30     XXXTentacion          Tina Turner         Taylor Swift
# 364 2023-12-31     XXXTentacion          Tina Turner         Taylor Swift
#
# [365 rows x 4 columns]

# %% [markdown]
# ### Output and Export
# Here, the processed data is saved to CSV files and prepared for download, suitable for offline analysis or sharing.

# %%
top_artists_by_day[['date', 'top_1', 'top_2', 'top_3']].to_csv("daily_visits")

# %% [markdown]
# ### Output and Export
# Here, the processed data is saved to CSV files and prepared for download, suitable for offline analysis or sharing.

# %%
daily_views = top_artists_by_day[['date', 'top_1', 'top_2', 'top_3']]

# %% [markdown]
# ### Data Import
# This section imports necessary libraries and loads data from an Excel file.

# %%
from google.colab import files
daily_views.to_csv('daily_views.csv', index=False)

# %% [markdown]
# ### Output and Export
# Here, the processed data is saved to CSV files and prepared for download, suitable for offline analysis or sharing.

# %%
files.download("daily_views.csv")

# %% [markdown]
# ### Output and Export
# Here, the processed data is saved to CSV files and prepared for download, suitable for offline analysis or sharing.

# %%
top_artists_by_day.to_csv("top_visits_per_day")
all_views_data.to_csv("NUMBER_of_views")

# %% [markdown]
# ### Additional Wikipedia Data Retrieval
# This section uses the Wikipedia API to fetch introductory paragraphs for top articles, adding context to the analysis.

# %%
pip install wikipedia-api
# Out:
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from wikipedia-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2024.2.2)
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.6.0

# %% [markdown]
# ### Data Import
# This section imports necessary libraries and loads data from an Excel file.

# %%
import wikipediaapi
import pandas as pd

# Load your dataset
df = pd.read_csv("/content/drive/MyDrive/top_visits_per_day")



wiki_wiki = wikipediaapi.Wikipedia(
    language='en',
    user_agent='YourAppName/1.0 (your-email@example.com)'
)

def get_wikipedia_intro(page_title):
    page = wiki_wiki.page(page_title)
    if page.exists():
        return page.summary
    else:
        return "Page not found"

# Apply the function to each artist in the "top_1" column
df['Introduction'] = df['top_1'].apply(get_wikipedia_intro)

# Save the updated dataframe with introductions
df.to_csv("artists_introduction.csv", index=False)

# If you want to display the first few rows to verify
print(df.head())
# Out:
#    Unnamed: 0        date                                        top_artists  \
# 0           0  2023-01-01  ['David Byrne', 'Miley Cyrus', 'The Pointer Si...
# 1           1  2023-01-02  ['Tanya Tucker', 'The Pointer Sisters', 'Tammy...
# 2           2  2023-01-03  ['Whitney Houston', 'Tammy Wynette', 'XXXTenta...
# 3           3  2023-01-04  ['XXXTentacion', 'Whitney Houston', 'Tammy Wyn...
# 4           4  2023-01-05  ['Shania Twain', 'XXXTentacion', 'Whitney Hous...
#
#              top_1                top_2                top_3  \
# 0      David Byrne          Miley Cyrus  The Pointer Sisters
# 1     Tanya Tucker  The Pointer Sisters        Tammy Wynette
# 2  Whitney Houston        Tammy Wynette         XXXTentacion
# 3     XXXTentacion      Whitney Houston        Tammy Wynette
# 4     Shania Twain         XXXTentacion      Whitney Houston
#
#                                         Introduction
# 0  David Byrne (; born 14 May 1952) is a Scottish...
# 1  Tanya Denise Tucker (born October 10, 1958) is...
# 2  Whitney Elizabeth Houston (August 9, 1963 – Fe...
# 3  Jahseh Dwayne Ricardo Onfroy (January 23, 1998...
# 4  Eilleen Regina "Shania" Twain  ( eye-LEEN ... ...
